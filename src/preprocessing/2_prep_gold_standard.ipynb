# %% [markdown]
# # Prepare & Sample Gold Standard Dataset

# %% [markdown]
# ## Overview
# This notebook ingests data from AWS Athena and samples 2000 notes for a 'gold standard' dataset - a subset of our raw data that is human-annotated for subsequent model training.
#
# It goes through several steps of preprocessing:
# - Reshaping through AWS Athena (not run here. See [../reference/additional_needs_reshape.py]()). This combines records from the MMH `notes` table with the `tenure` table to make every note attributed to its relevant tenancy.
#
# - Loading data from our newly made `additional_needs_notes_reshaped` table through Athena. [Link](#acquire-data).
#
# - Acronym Exapansion. Finds commons acronyms in the note. These are then replaced with regexes with their expanded versions (human-verified). [Link](#expand-acronyms).
#
# - Weak labelling using regexes. [Link](#weak-labeling-via-regex).
#
# - Exploratory Data Analysis. [Link](#exploratory-data-analysis).
#
# - Removes low-prevalence labels. [Link](#drop-rare-categories).
#
# - Stratified Sampling using the regexes as a heuristic (45 examples per class - 40*45 = 1800, 1800 + 200 'zero match' classes add to 2000 notes). [Link](#stratified-sample-n2000).
#
# - PII redaction. Strips Personally Identifiable Information (PII) from the gold standard set. Replaces names with autogenerated fake names. [Link](#pii-personally-identifiable-information-redaction).
#
# - Pre-annotation. Uses the regexes to pre-annotate the notes with the correct span (the specific words, e.g. 'resident uses a wheelchair'). [Link](#pre-annotation).
#
# - Exports to CSV and JSON. [Link](#export-sample-set).
#
# **Note: Unredacted data is never persisted on the local device. This is intentional as it prevents data protection issues around storing resident data on local devices, but it means that re-running this file on different days will likely produce different results due to new notes being added to upstream data sources. Keep this in mind as your new reruns could overwrite previous exports.**

# %% [markdown]
# ## Environment Setup

# %%
# Imports
import pandas as pd
import numpy as np
import json
import re
from dataclasses import dataclass

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

from tqdm.notebook import tqdm
from pandarallel import pandarallel

import boto3
import awswrangler as wr

import nltk
from collections import Counter
from nltk.corpus import words

from presidio_analyzer import AnalyzerEngine, PatternRecognizer, Pattern
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig
from faker import Faker

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent / "src"))

from common.paths import RAW, PROCESSED
from common.graph_helpers import analyze_category_distribution_from_df, plot_cooccurrence_heatmap
from common.logging import setup_logger
from eval.evaluators import SpanEvaluator

# %%
@dataclass
class AwsConfig:
    aws_region = "eu-west-2"
    aws_profile = "data-platform-housing-prod"
    database_name = "housing-refined-zone"
    table_name = "additional_needs_notes_reshaped"

@dataclass
class Config:
    logger = setup_logger('preprocessing.sample_gold_standard')
    AWS = AwsConfig()

    random_state = 42
    target_total = 2000
    target_per_cat = 45

    # Paths
    taxonomy_path_v1 = PROCESSED / "taxonomy_autogen_v1.csv"
    taxonomy_path_v2 = PROCESSED / "taxonomy_autogen_v2.csv"
    output_gold_standard_json_path = PROCESSED / "gold_standard_sample.json"
    output_gold_standard_csv_path = PROCESSED / "gold_standard_sample.csv"
    regex_matches_path = PROCESSED / "full_dataset_regex_matches.csv"

    # PII entites to redact
    redact_entities = [
        "PERSON", 
        "EMAIL_ADDRESS", 
        "PHONE_NUMBER", 
        "DATE_TIME",
        "LOCATION",
        "UK_POSTCODE", 
        "CREDIT_CARD", 
        "IBAN_CODE", 
        "IP_ADDRESS",
        "URL"
    ]

config = Config()

# %%
# Tool setups

# NLTK
nltk.download('words')

# Pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# [nltk_data] Downloading package words to /Users/arawat/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Acquire Data
# Get latest data from AWS Athena.

# %%
def fetch_data_from_athena():
    session = boto3.Session(region_name=config.AWS.aws_region, profile_name=config.AWS.aws_profile)

    sql_query = f''' SELECT DISTINCT note_id, note_content, note_category
                    FROM "{config.AWS.database_name}".{config.AWS.table_name}
                    WHERE flag_no_matching_target = FALSE
                        AND flag_note_date_parse_failed = FALSE
                        AND flag_is_organisation = FALSE
                        AND flag_inactive = FALSE;
    '''

    return wr.athena.read_sql_query(sql_query, database=config.AWS.database_name, boto3_session=session, ctas_approach=False)

df = fetch_data_from_athena()

# %%
if not df['note_content'].str.startswith('[Category:').all():
    # Prevents this from running twice
    df['note_content'] = "[Category: " + df['note_category'] + "] " + df['note_content']
df.head()
# Out:
#                                 note_id  \
# 0  edebb10c-ad5a-4e49-7c4f-10268bc8de57
# 1  f0d1345d-73eb-dfd5-561e-c9e9e4584c35
# 2  076659ae-615c-7299-08a5-afc39fa95e61
# 3  55f0bc4d-db05-e1ac-350a-58c5d5b1fcf3
# 4  be7b8f6b-aa40-3977-69eb-d33d9766c704
#
#                                         note_content       note_category
# 0  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 1           [Category: Rents] Mail merge letter sent               Rents
# 2  [Category: Tenancy Management] Mailing address...  Tenancy Management
# 3  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 4  [Category: Tenancy Management] tel call from a...  Tenancy Management

# %% [markdown]
# ## Expand Acronyms
# Discover common acronyms (2-4 letter words that aren't in the English dictionary) and replace them with their expanded forms.

# %%
def get_most_common_acronyms(series: pd.Series, n: int = 100) -> list:
    # Load the standard English dictionary into a lookup set
    english_vocab = set(word.lower() for word in words.words())

    # Find 2-4 letter words (pre-compile for speed)
    acronym_pattern = re.compile(r'\b[a-z]{2,4}\b')
    
    acronym_counter = Counter()

    # Stream and update row-by-row
    for text in series.dropna():
        if isinstance(text, str):
            # Find short words and filter ones that aren't in the dictionary
            short_words = acronym_pattern.findall(text.lower())
            acronyms_only = [word for word in short_words if word not in english_vocab]
            
            # Batch update the counter
            acronym_counter.update(acronyms_only)

    return acronym_counter.most_common(n)

get_most_common_acronyms(df['note_content'], n=100)
# Out:
# [('tnt', 169078),
#  ('has', 164102),
#  ('lh', 61133),
#  ('uk', 60426),
#  ('gov', 50291),
#  ('ms', 40702),
#  ('asb', 39155),
#  ('cb', 31600),
#  ('hb', 29128),
#  ('paid', 22664),
#  ('sc', 18404),
#  ('keys', 15099),
#  ('rcc', 14887),
#  ('cc', 14638),
#  ('hsc', 14346),
#  ('tel', 13846),
#  ('says', 13308),
#  ('ange', 12616),
#  ('dd', 12483),
#  ('doua', 12135),
#  ('com', 12040),
#  ('pls', 10942),
#  ('rtb', 9709),
#  ('auth', 9556),
#  ('eo', 9223),
#  ('cleo', 7624),
#  ('nosp', 7307),
#  ('co', 6574),
#  ('wba', 5918),
#  ('info', 5658),
#  ('uhw', 5389),
#  ('olu', 5181),
#  ('nho', 5053),
#  ('fobs', 4977),
#  ('mpa', 4953),
#  ('bacs', 4900),
#  ('docs', 4737),
#  ('mw', 4634),
#  ('rec', 4584),
#  ('ali', 4552),
#  ('tnts', 4478),
#  ('hh', 4441),
#  ('appt', 4304),
#  ('app', 4198),
#  ('ntq', 4081),
#  ('ncst', 3862),
#  ('itv', 3803),
#  ('uc', 3704),
#  ('acc', 3576),
#  ('ve', 3478),
#  ('emre', 3322),
#  ('gge', 3281),
#  ('mmh', 3195),
#  ('etc', 3049),
#  ('acct', 2935),
#  ('kaur', 2812),
#  ('feb', 2775),
#  ('org', 2726),
#  ('tmo', 2719),
#  ('uht', 2693),
#  ('www', 2684),
#  ('didn', 2680),
#  ('kofi', 2678),
#  ('nb', 2652),
#  ('nom', 2644),
#  ('ahm', 2615),
#  ('uh', 2585),
#  ('vm', 2583),
#  ('recd', 2559),
#  ('asap', 2508),
#  ('hasn', 2403),
#  ('nov', 2310),
#  ('msg', 2268),
#  ('cust', 2262),
#  ('oct', 2238),
#  ('dec', 2226),
#  ('ac', 2224),
#  ('lbh', 2097),
#  ('pm', 2015),
#  ('aug', 1862),
#  ('cst', 1745),
#  ('ot', 1727),
#  ('dv', 1683),
#  ('ll', 1678),
#  ('cert', 1644),
#  ('elli', 1643),
#  ('pd', 1639),
#  ('dlo', 1569),
#  ('gets', 1555),
#  ('cctv', 1530),
#  ('cs', 1511),
#  ('rd', 1486),
#  ('ct', 1463),
#  ('gp', 1457),
#  ('wasn', 1418),
#  ('mex', 1409),
#  ('ctax', 1399),
#  ('nhs', 1362),
#  ('uju', 1357),
#  ('lr', 1323)]

# %% [markdown]
# ### Replace acronyms
# We looked at the common acronyms from the cell above and constructed a *normalisation dictionary*.

# %%
abbreviation_mapping = {
    # Hackney terms
    r'\bhsc\b': 'Hackney Service Centre',
    r'\bmmh\b': 'Manage My Home',
    r'\blbh\b': 'London Borough of Hackney',
    r'\brcc\b': 'Repairs Contact Centre',

    # Housing terms
    r'\btnt\b': 'tenant',
    r'\bclt\b': 'client',
    r'\btnts\b': 'tenants',
    r'\bl/h\b': 'leaseholder',
    r'\bh/o\b': 'housing officer',
    r'\btmo\b': 'Tenant Management Organisation',
    r'\bnho\b': 'neighbourhood housing officer',
    r'\bahm\b': 'area housing manager',
    r'\bhb\b': 'housing benefit',
    r'\bnosp\b': 'Notice of Seeking Possession',
    r'\bntq\b': 'Notice to Quit',
    r'\brtb\b': 'Right to Buy',
    r'\buc\b': 'Universal Credit',
    r'\basb\b': 'anti-social behaviour',
    r'\bdv\b': 'domestic violence',
    r'\bda\b': 'domestic abuse',

    # General terms
    r'\btel\b': 'telephone',
    r'\bdocs\b': 'documents',
    r'\bappt\b': 'appointment',
    r'\bacct\b': 'account',
    r'\bbacs\b': 'bank transfer',
    r'\binfo\b': 'information',
    r'\borg\b': 'organisation',
    r'\bsms\b': 'text message',
    r'\bmsg\b': 'message',
    r'\bcctv\b': 'camera',
    r'\bgp\b': 'general practitioner',
    r'\bpls\b': 'please',
    r'\brecd\b': 'received',
    r'\basap\b': 'as soon as possible',
    r'\bpls\b': 'please',
    r'\bcert\b': 'certificate',
    r'\bvm\b': 'voicemail',
}

# %%
acronym_substitution_patterns = [(re.compile(p, re.IGNORECASE), r) for p, r in abbreviation_mapping.items()]

def normalize_acronyms(text):
    if pd.isna(text):
        return text
    for pattern, replacement in acronym_substitution_patterns:
        text = pattern.sub(replacement, text)
    return text

df['note_content'] = df['note_content'].parallel_apply(normalize_acronyms)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=87189), Label(value='0 / 87189')))…

# %% [markdown]
# ## Weak Labeling via Regex
# Apply the regex patterns from the taxonomy csv to assign 'weak labels' to the dataset.

# %%
taxonomy = pd.read_csv(config.taxonomy_path_v1)

# %%
category_regex_patterns = [(row.cat_label, re.compile(row.regex, re.IGNORECASE)) for row in taxonomy.itertuples()] # type: ignore

def flag_category_matches(series):
    """
    Apply all category regexes to a pandas Series of texts.
    Returns a DataFrame of boolean flags.
    """
    def apply_all_categories(text):
        return {label: bool(pattern.search(text)) for label, pattern in category_regex_patterns}

    results = series.fillna('').parallel_apply(apply_all_categories)
    return pd.DataFrame(results.tolist())

df = df.join(flag_category_matches(df['note_content']))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=87189), Label(value='0 / 87189')))…

# %%
df.head()
# Out:
#                                 note_id  \
# 0  edebb10c-ad5a-4e49-7c4f-10268bc8de57
# 1  f0d1345d-73eb-dfd5-561e-c9e9e4584c35
# 2  076659ae-615c-7299-08a5-afc39fa95e61
# 3  55f0bc4d-db05-e1ac-350a-58c5d5b1fcf3
# 4  be7b8f6b-aa40-3977-69eb-d33d9766c704
#
#                                         note_content       note_category  \
# 0  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 1           [Category: Rents] Mail merge letter sent               Rents
# 2  [Category: Tenancy Management] Mailing address...  Tenancy Management
# 3  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 4  [Category: Tenancy Management] telephone call ...  Tenancy Management
#
#    care_care_experienced  care_care_setting  care_has_caring_responsibility  \
# 0                  False              False                           False
# 1                  False              False                           False
# 2                  False              False                           False
# 3                  False              False                           False
# 4                  False              False                           False
#
#    care_social_care_involvement  cautions_asbo_or_injunction_obtained  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    cautions_dangerous_animals  cautions_visiting_requirements  ...  \
# 0                       False                           False  ...
# 1                       False                           False  ...
# 2                       False                           False  ...
# 3                       False                           False  ...
# 4                       False                           False  ...
#
#    mobility_service_need  property_level_property_adapted  \
# 0                  False                            False
# 1                  False                            False
# 2                  False                            False
# 3                  False                            False
# 4                  False                            False
#
#    property_level_disrepair_damp_mould  property_level_infestation  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                 True                       False
# 4                                False                       False
#
#    safety_risk_antisocial_behaviour  safety_risk_domestic_abuse  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
#
#    safety_risk_firerelated_risks  safety_risk_gas_capped  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
#
#    safety_risk_risk_of_exploitation  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    safety_risk_gang_activity_serious_youth_violence
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
# [5 rows x 45 columns]

# %%
# Save out (without sensitive data)
df.drop('note_content', axis=1).to_csv(config.regex_matches_path, index=False)

# %% [markdown]
# ## Exploratory Data Analysis
# Analyze the distribution of the weak labels to understand class imbalances and inform stratified sampling. Analyse which labels co-occur.

# %%
def display_note_lengths_hist(df):
    # Length of notes in words (histogram)
    note_length_words = df['note_content'].fillna('').str.split().apply(len)

    # Histogram of note lengths
    ax = sns.histplot(note_length_words, bins=50)

    mean_val = note_length_words.mean()
    ax.axvline(mean_val, color='black', linestyle='--')
    ax.text(mean_val, ax.get_ylim()[1] * 0.9, f'Mean: {mean_val:.0f} words', color='black')

    ax.set(title='Distribution of Note Lengths (in Words)', xlabel='Number of Words', ylabel='Frequency')
    plt.show()

display_note_lengths_hist(df)

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(df.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_6a51d_row0_col2, #T_6a51d_row1_col2, #T_6a51d_row2_col2, #T_6a51d_row3_col2, #T_6a51d_row4_col2, #T_6a51d_row5_col2, #T_6a51d_row6_col2, #T_6a51d_row7_col2, #T_6a51d_row8_col2, #T_6a51d_row9_col2, #T_6a51d_row10_col2, #T_6a51d_row11_col2, #T_6a51d_row12_col2, #T_6a51d_row13_col2, #T_6a51d_row14_col2, #T_6a51d_row15_col2, #T_6a51d_row16_col2, #T_6a51d_row17_col2, #T_6a51d_row18_col2, #T_6a51d_row19_col2, #T_6a51d_row20_col2, #T_6a51d_row21_col2, #T_6a51d_row22_col2, #T_6a51d_row23_col2, #T_6a51d_row24_col2, #T_6a51d_row25_col2, #T_6a51d_row26_col2, #T_6a51d_row27_col2, #T_6a51d_row28_col2, #T_6a51d_row29_col2, #T_6a51d_row30_col2, #T_6a51d_row31_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6a51d_row32_col2, #T_6a51d_row33_col2, #T_6a51d_row34_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_6a51d_row35_col2, #T_6a51d_row36_col2, #T_6a51d_row37_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_6a51d_row38_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_6a51d_row39_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_6a51d_row40_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_6a51d_row41_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a51d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a51d_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_6a51d_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_6a51d_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a51d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a51d_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_6a51d_row0_col1" class="data row0 col1" >56312</td>
#       <td id="T_6a51d_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a51d_row1_col0" class="data row1 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_6a51d_row1_col1" class="data row1 col1" >32379</td>
#       <td id="T_6a51d_row1_col2" class="data row1 col2" >1.739152</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a51d_row2_col0" class="data row2 col0" >property_level_infestation</td>
#       <td id="T_6a51d_row2_col1" class="data row2 col1" >5411</td>
#       <td id="T_6a51d_row2_col2" class="data row2 col2" >10.406949</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a51d_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_6a51d_row3_col1" class="data row3 col1" >4777</td>
#       <td id="T_6a51d_row3_col2" class="data row3 col2" >11.788152</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a51d_row4_col0" class="data row4 col0" >life_events_temporary</td>
#       <td id="T_6a51d_row4_col1" class="data row4 col1" >4178</td>
#       <td id="T_6a51d_row4_col2" class="data row4 col2" >13.478219</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a51d_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_6a51d_row5_col1" class="data row5 col1" >3601</td>
#       <td id="T_6a51d_row5_col2" class="data row5 col2" >15.637878</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a51d_row6_col0" class="data row6 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_6a51d_row6_col1" class="data row6 col1" >3120</td>
#       <td id="T_6a51d_row6_col2" class="data row6 col2" >18.048718</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a51d_row7_col0" class="data row7 col0" >health_substance_misuse</td>
#       <td id="T_6a51d_row7_col1" class="data row7 col1" >2833</td>
#       <td id="T_6a51d_row7_col2" class="data row7 col2" >19.877162</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a51d_row8_col0" class="data row8 col0" >care_social_care_involvement</td>
#       <td id="T_6a51d_row8_col1" class="data row8 col1" >1841</td>
#       <td id="T_6a51d_row8_col2" class="data row8 col2" >30.587724</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a51d_row9_col0" class="data row9 col0" >safety_risk_firerelated_risks</td>
#       <td id="T_6a51d_row9_col1" class="data row9 col1" >1751</td>
#       <td id="T_6a51d_row9_col2" class="data row9 col2" >32.159909</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a51d_row10_col0" class="data row10 col0" >reasonable_adjustments_mental_capacity</td>
#       <td id="T_6a51d_row10_col1" class="data row10 col1" >1726</td>
#       <td id="T_6a51d_row10_col2" class="data row10 col2" >32.625724</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a51d_row11_col0" class="data row11 col0" >health_care_setting</td>
#       <td id="T_6a51d_row11_col1" class="data row11 col1" >1714</td>
#       <td id="T_6a51d_row11_col2" class="data row11 col2" >32.854142</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6a51d_row12_col0" class="data row12 col0" >cautions_dangerous_animals</td>
#       <td id="T_6a51d_row12_col1" class="data row12 col1" >1563</td>
#       <td id="T_6a51d_row12_col2" class="data row12 col2" >36.028151</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6a51d_row13_col0" class="data row13 col0" >life_events_life_events</td>
#       <td id="T_6a51d_row13_col1" class="data row13 col1" >1216</td>
#       <td id="T_6a51d_row13_col2" class="data row13 col2" >46.309211</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6a51d_row14_col0" class="data row14 col0" >housing_conditions_hoarding</td>
#       <td id="T_6a51d_row14_col1" class="data row14 col1" >1010</td>
#       <td id="T_6a51d_row14_col2" class="data row14 col2" >55.754455</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6a51d_row15_col0" class="data row15 col0" >health_neurodiversity_learning_disability</td>
#       <td id="T_6a51d_row15_col1" class="data row15 col1" >886</td>
#       <td id="T_6a51d_row15_col2" class="data row15 col2" >63.557562</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6a51d_row16_col0" class="data row16 col0" >mobility_mobility_physical</td>
#       <td id="T_6a51d_row16_col1" class="data row16 col1" >756</td>
#       <td id="T_6a51d_row16_col2" class="data row16 col2" >74.486772</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6a51d_row17_col0" class="data row17 col0" >disability_requires_adapted_property</td>
#       <td id="T_6a51d_row17_col1" class="data row17 col1" >755</td>
#       <td id="T_6a51d_row17_col2" class="data row17 col2" >74.585430</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6a51d_row18_col0" class="data row18 col0" >property_level_property_adapted</td>
#       <td id="T_6a51d_row18_col1" class="data row18 col1" >752</td>
#       <td id="T_6a51d_row18_col2" class="data row18 col2" >74.882979</td>
#     </tr>
#     <tr>
#       <th id="T_6a51d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6a51d_row19_col0" class="data row19 col0" >c
# <style type="text/css">
# </style>
# <table id="T_22d2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22d2e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_22d2e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22d2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22d2e_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_22d2e_row0_col1" class="data row0 col1" >1637.01</td>
#     </tr>
#     <tr>
#       <th id="T_22d2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22d2e_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_22d2e_row1_col1" class="data row1 col1" >56312.00</td>
#     </tr>
#     <tr>
#       <th id="T_22d2e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22d2e_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_22d2e_row2_col1" class="data row2 col1" >5.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Number of notes that have at least one category match
bool_cols = df.select_dtypes(include=["bool"])
true_row_count = bool_cols.any(axis=1).sum()
print("%.2f" % (true_row_count/len(df) * 100) + "%")
# Out:
# 16.69%

# %%
plot_cooccurrence_heatmap(df, taxonomy)
# Out:
# <Axes: title={'center': 'Label Co-occurrence'}, xlabel='Categories', ylabel='Categories'>

# %% [markdown]
# ### Drop rare categories
# Based on the EDA, drop categories to address class imbalance and ensure sufficient representation for sampling. Dropped categories will only rely on regex instead.

# %%
df_v2 = df.copy()
taxonomy_v2 = taxonomy.copy()

dropped_categories = [
    'life_events_identity', # Only one hit. Should drop.
    'cautions_visiting_requirements', # 12 hits
    'safety_risk_gang_activity_serious_youth_violence', # 33 hits
]

df_v2.drop(columns=dropped_categories, inplace=True)
mask = taxonomy_v2['cat_label'].isin(dropped_categories)
taxonomy_v2 = taxonomy_v2[~mask].reset_index(drop=True)
taxonomy_v2.to_csv(config.taxonomy_path_v2, index=False)

taxonomy_v2.head()
# Out:
#   high_level_category         category_description  \
# 0                Care             Care experienced
# 1                Care                 Care setting
# 2                Care    Has caring responsibility
# 3                Care      Social care involvement
# 4            Cautions  ASBO or injunction obtained
#
#                                        values_hint  \
# 0   ['Care leaver', 'Care experienced (under 25)']
# 1                      ['Fostered', 'Social care']
# 2                           ['Formal', 'Informal']
# 3  ['Adult Social Care', "Children's Social Care"]
# 4                           ['ASBO', 'Injunction']
#
#                               cat_label  \
# 0                 care_care_experienced
# 1                     care_care_setting
# 2        care_has_caring_responsibility
# 3          care_social_care_involvement
# 4  cautions_asbo_or_injunction_obtained
#
#                                                regex
# 0  \bcare experienced\b|\bcare leaver\b|\baged ou...
# 1  \bfostered\b|\bfoster care\b|\bfoster placemen...
# 2  \bformal carer\b|\bregistered carer\b|\bcarer....
# 3  \bsocial care\b|\bcare package\b|\bcare plan\b...
# 4  \bASBO\b|\binjunction\b|\bcivil injunction\b|\...

# %%
del df # memory saving

# %% [markdown]
# ### Compare class imbalance
# Compare the class imbalance before and after combining/dropping categories to assess the impact on the dataset.

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(df_v2.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy_v2, log_scale=False)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_59466_row0_col2, #T_59466_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_59466_row2_col2, #T_59466_row3_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_59466_row4_col2, #T_59466_row5_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_59466_row6_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_59466_row7_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_59466_row8_col2, #T_59466_row9_col2, #T_59466_row10_col2, #T_59466_row11_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_59466_row12_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_59466_row13_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_59466_row14_col2 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_59466_row15_col2 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_59466_row16_col2, #T_59466_row17_col2, #T_59466_row18_col2, #T_59466_row19_col2 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_59466_row20_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_59466_row21_col2 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_59466_row22_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_59466_row23_col2 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_59466_row24_col2, #T_59466_row25_col2 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_59466_row26_col2 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_59466_row27_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_59466_row28_col2 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_59466_row29_col2 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_59466_row30_col2 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_59466_row31_col2 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_59466_row32_col2 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_59466_row33_col2 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_59466_row34_col2 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_59466_row35_col2 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_59466_row36_col2 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_59466_row37_col2 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_59466_row38_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_59466">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59466_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_59466_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_59466_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59466_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59466_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_59466_row0_col1" class="data row0 col1" >56312</td>
#       <td id="T_59466_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59466_row1_col0" class="data row1 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_59466_row1_col1" class="data row1 col1" >32379</td>
#       <td id="T_59466_row1_col2" class="data row1 col2" >1.739152</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59466_row2_col0" class="data row2 col0" >property_level_infestation</td>
#       <td id="T_59466_row2_col1" class="data row2 col1" >5411</td>
#       <td id="T_59466_row2_col2" class="data row2 col2" >10.406949</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59466_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_59466_row3_col1" class="data row3 col1" >4777</td>
#       <td id="T_59466_row3_col2" class="data row3 col2" >11.788152</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59466_row4_col0" class="data row4 col0" >life_events_temporary</td>
#       <td id="T_59466_row4_col1" class="data row4 col1" >4178</td>
#       <td id="T_59466_row4_col2" class="data row4 col2" >13.478219</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_59466_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_59466_row5_col1" class="data row5 col1" >3601</td>
#       <td id="T_59466_row5_col2" class="data row5 col2" >15.637878</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_59466_row6_col0" class="data row6 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_59466_row6_col1" class="data row6 col1" >3120</td>
#       <td id="T_59466_row6_col2" class="data row6 col2" >18.048718</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_59466_row7_col0" class="data row7 col0" >health_substance_misuse</td>
#       <td id="T_59466_row7_col1" class="data row7 col1" >2833</td>
#       <td id="T_59466_row7_col2" class="data row7 col2" >19.877162</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_59466_row8_col0" class="data row8 col0" >care_social_care_involvement</td>
#       <td id="T_59466_row8_col1" class="data row8 col1" >1841</td>
#       <td id="T_59466_row8_col2" class="data row8 col2" >30.587724</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_59466_row9_col0" class="data row9 col0" >safety_risk_firerelated_risks</td>
#       <td id="T_59466_row9_col1" class="data row9 col1" >1751</td>
#       <td id="T_59466_row9_col2" class="data row9 col2" >32.159909</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_59466_row10_col0" class="data row10 col0" >reasonable_adjustments_mental_capacity</td>
#       <td id="T_59466_row10_col1" class="data row10 col1" >1726</td>
#       <td id="T_59466_row10_col2" class="data row10 col2" >32.625724</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_59466_row11_col0" class="data row11 col0" >health_care_setting</td>
#       <td id="T_59466_row11_col1" class="data row11 col1" >1714</td>
#       <td id="T_59466_row11_col2" class="data row11 col2" >32.854142</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_59466_row12_col0" class="data row12 col0" >cautions_dangerous_animals</td>
#       <td id="T_59466_row12_col1" class="data row12 col1" >1563</td>
#       <td id="T_59466_row12_col2" class="data row12 col2" >36.028151</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_59466_row13_col0" class="data row13 col0" >life_events_life_events</td>
#       <td id="T_59466_row13_col1" class="data row13 col1" >1216</td>
#       <td id="T_59466_row13_col2" class="data row13 col2" >46.309211</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_59466_row14_col0" class="data row14 col0" >housing_conditions_hoarding</td>
#       <td id="T_59466_row14_col1" class="data row14 col1" >1010</td>
#       <td id="T_59466_row14_col2" class="data row14 col2" >55.754455</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_59466_row15_col0" class="data row15 col0" >health_neurodiversity_learning_disability</td>
#       <td id="T_59466_row15_col1" class="data row15 col1" >886</td>
#       <td id="T_59466_row15_col2" class="data row15 col2" >63.557562</td>
#     </tr>
#     <tr>
#       <th id="T_59466_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_59466_row16_
# <style type="text/css">
# </style>
# <table id="T_5a3dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a3dc_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_5a3dc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a3dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a3dc_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_5a3dc_row0_col1" class="data row0 col1" >154.96</td>
#     </tr>
#     <tr>
#       <th id="T_5a3dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a3dc_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_5a3dc_row1_col1" class="data row1 col1" >938.53</td>
#     </tr>
#     <tr>
#       <th id="T_5a3dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a3dc_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_5a3dc_row2_col1" class="data row2 col1" >1.30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Construct Gold Standard Set
# Uses *iterative random sampling*, which is a common technique to perform stratified sampling on a multi-label dataset. We start by choosing n=45 examples of the least prevalent class and then continue with the rest of the labels, removing examples that have already been sampled. This helps to balance the dataset where examples can have multiple labels.

# %% [markdown]
# ### Stratified Sample (n=2000)
# Perform stratified sampling based on the weak labels to create a balanced gold standard dataset of 2000 records for manual annotation.

# %%
# Get unflagged records - zero category matches.
df_v2['unflagged'] = ~df_v2[taxonomy_v2['cat_label']].any(axis=1)
df_v2['unflagged'].value_counts()
# Out:
# unflagged
# True     581090
# False    116419
# Name: count, dtype: int64

# %%
def sample_gold_standard(df, taxonomy):
    sampled_data = []
    sampled_ids = set()

    # Sample categories by least prevalent (up to config.target_per_cat)
    category_counts = df[taxonomy['cat_label']].sum().sort_values(ascending=True)
    for cat in category_counts.index:
        pool = df[df[cat] & ~df['note_id'].isin(sampled_ids)] # In the category and not already sampled
        n = min(len(pool), config.target_per_cat)
        if n > 0:
            sample = pool.sample(n=n, random_state=config.random_state) # Random sample
            sampled_data.append(sample)
            sampled_ids.update(sample['note_id'].tolist())

    # Sample unflagged (non-category matches) records
    pool = df[df['unflagged'] & ~df['note_id'].isin(sampled_ids)]
    n = min(len(pool), config.target_total - len(sampled_ids))
    if n > 0:
        sample = pool.sample(n=n, random_state=config.random_state)
        sampled_data.append(sample)
        sampled_ids.update(sample['note_id'].tolist())

    # Combine and shuffle
    return pd.concat(sampled_data).sample(frac=1, random_state=config.random_state).reset_index(drop=True)

# %%
final_sample = sample_gold_standard(df_v2, taxonomy_v2)
final_sample.drop(columns=['note_id', 'note_content', 'note_category']).sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 final_sample = sample_gold_standard(df_v2, taxonomy_v2)
#       2 final_sample.drop(columns=['note_id', 'note_content', 'note_category']).sum().sort_values()
#
# Cell In[21], line 8, in sample_gold_standard(df, taxonomy)
#       4
#       5     # Sample categories by least prevalent (up to config.target_per_cat)
#       6     category_counts = df[taxonomy['cat_label']].sum().sort_values(ascending=True)
#       7     for cat in category_counts.index:
# ----> 8         pool = df[df[cat] & ~df['note_id'].isin(sampled_ids)] # In the category and not already sampled
#       9         n = min(len(pool), config.target_per_cat)
#      10         if n > 0:
#      11             sample = pool.sample(n=n, random_state=config.random_state) # Random sample
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4369, in DataFrame.__getitem__(self, key)
#    4365             return self.where(key)
#    4366
#    4367         # Do we have a (boolean) 1d indexer?
#    4368         if com.is_bool_indexer(key):
# -> 4369             return self._getitem_bool_array(key)
#    4370
#    4371         # We are left with two options: a single key, and a collection of keys,
#    4372         # We interpret tuples as collections only for non-MultiIndex
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4431, in DataFrame._getitem_bool_array(self, key)
#    4427         if key.all():
#    4428             return self.copy(deep=False)
#    4429
#    4430         indexer = key.nonzero()[0]
# -> 4431         return self.take(indexer, axis=0)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/generic.py:4101, in NDFrame.take(self, indices, axis, **kwargs)
#    4097         indices = np.asarray(indices, dtype=np.intp)
#    4098         if axis == 0 and indices.ndim == 1 and is_range_indexer(indices, len(self)):
#    4099             return self.copy(deep=False)
#    4100
# -> 4101         new_data = self._mgr.take(
#    4102             indices,
#    4103             axis=self._get_block_manager_axis(axis),
#    4104             verify=True,
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:1077, in BaseBlockManager.take(self, indexer, axis, verify)
#    1074 indexer = maybe_convert_indices(indexer, n, verify=verify)
#    1076 new_labels = self.axes[axis].take(indexer)
# -> 1077 return self.reindex_indexer(
#    1078     new_axis=new_labels,
#    1079     indexer=indexer,
#    1080     axis=axis,
#    1081     allow_dups=True,
#    1082 )
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:866, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, only_slice, use_na_proxy)
#     863             new_blocks.append(NumpyBlock(vals, blk.mgr_locs, ndim=2))
#     864         else:
#     865             new_blocks.append(
# --> 866                 blk.take_nd(
#     867                     indexer,
#     868                     axis=1,
#     869                     fill_value=(
#     870                         fill_value if fill_value is not None else blk.fill_value
#     871                     ),
#     872                 )
#     873             )
#     875 new_axes = list(self.axes)
#     876 new_axes[axis] = new_axis
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1015, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1012     allow_fill = True
#    1014 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1015 new_values = algos.take_nd(
#    1016     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1017 )
#    1019 # Called from three places in managers, all of which satisfy
#    1020 #  these assertions
#    1021 if isinstance(self, ExtensionBlock):
#    1022     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1023     #  algos.take_nd call above.
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/array_algos/take.py:112, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     107         arr = cast("NDArrayBackedExtensionArray", arr)
#     108         return arr.take(
#     109             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     110         )
# --> 112     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     114 arr = np.asarray(arr)
#     115 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:1634, in ArrowExtensionArray.take(self, indices, allow_fill, fill_value)
#    1630         return result
#    1631         # return type(self)(pc.fill_null(result, pa.scalar(fill_value)))
#    1632     else:
#    1633         # Nothing to fill
# -> 1634         return self._from_pyarrow_array(self._pa_array.take(indices))
#    1635 else:  # allow_fill=False
#    1636     # TODO(ARROW-9432): Treat negative indices as indices from the right.
#    1637     if (indices_array < 0).any():
#    1638         # Don't modify in-place
#
# File pyarrow/table.pxi:1083, in pyarrow.lib.ChunkedArray.take()
# -> 1083 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pyarrow/compute.py:508, in take(data, indices, boundscheck, memory_pool)
#     468 """
#     469 Select values (or records) from array- or table-like data given integer
#     470 selection indices.
#    (...)    505 ]
#     506 """
#     507 options = TakeOptions(boundscheck=boundscheck)
# --> 508 return call_function('take', [data, indices], options, memory_pool)
#
# KeyboardInterrupt:

# %%
del df_v2 # Memory saving

# %% [markdown]
# ### Compare class imbalance
# Compare the class imbalance in the gold standard set to the original dataset to evaluate the effectiveness of the sampling strategy.

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(final_sample.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy_v2, log_scale=False)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_c1316_row0_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c1316_row1_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_c1316_row2_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_c1316_row3_col2 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_c1316_row4_col2 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_c1316_row5_col2 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_c1316_row6_col2, #T_c1316_row7_col2 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_c1316_row8_col2 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_c1316_row9_col2 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_c1316_row10_col2 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_c1316_row11_col2 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_c1316_row12_col2 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_c1316_row13_col2 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_c1316_row14_col2, #T_c1316_row15_col2 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_c1316_row16_col2 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_c1316_row17_col2 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_c1316_row18_col2, #T_c1316_row19_col2 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_c1316_row20_col2 {
#   background-color: #de2b25;
#   color: #f1f1f1;
# }
# #T_c1316_row21_col2 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_c1316_row22_col2, #T_c1316_row23_col2 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_c1316_row24_col2 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_c1316_row25_col2, #T_c1316_row26_col2, #T_c1316_row27_col2, #T_c1316_row28_col2 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_c1316_row29_col2, #T_c1316_row30_col2 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_c1316_row31_col2 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_c1316_row32_col2, #T_c1316_row33_col2, #T_c1316_row34_col2 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_c1316_row35_col2, #T_c1316_row36_col2, #T_c1316_row37_col2 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_c1316_row38_col2, #T_c1316_row39_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1316">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1316_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_c1316_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_c1316_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1316_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1316_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_c1316_row0_col1" class="data row0 col1" >317</td>
#       <td id="T_c1316_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1316_row1_col0" class="data row1 col0" >unflagged</td>
#       <td id="T_c1316_row1_col1" class="data row1 col1" >245</td>
#       <td id="T_c1316_row1_col2" class="data row1 col2" >1.293878</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1316_row2_col0" class="data row2 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_c1316_row2_col1" class="data row2 col1" >197</td>
#       <td id="T_c1316_row2_col2" class="data row2 col2" >1.609137</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1316_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_c1316_row3_col1" class="data row3 col1" >142</td>
#       <td id="T_c1316_row3_col2" class="data row3 col2" >2.232394</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1316_row4_col0" class="data row4 col0" >mobility_mobility_physical</td>
#       <td id="T_c1316_row4_col1" class="data row4 col1" >109</td>
#       <td id="T_c1316_row4_col2" class="data row4 col2" >2.908257</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c1316_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_c1316_row5_col1" class="data row5 col1" >102</td>
#       <td id="T_c1316_row5_col2" class="data row5 col2" >3.107843</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c1316_row6_col0" class="data row6 col0" >property_level_property_adapted</td>
#       <td id="T_c1316_row6_col1" class="data row6 col1" >95</td>
#       <td id="T_c1316_row6_col2" class="data row6 col2" >3.336842</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c1316_row7_col0" class="data row7 col0" >disability_requires_adapted_property</td>
#       <td id="T_c1316_row7_col1" class="data row7 col1" >95</td>
#       <td id="T_c1316_row7_col2" class="data row7 col2" >3.336842</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c1316_row8_col0" class="data row8 col0" >housing_conditions_hoarding</td>
#       <td id="T_c1316_row8_col1" class="data row8 col1" >92</td>
#       <td id="T_c1316_row8_col2" class="data row8 col2" >3.445652</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c1316_row9_col0" class="data row9 col0" >health_care_setting</td>
#       <td id="T_c1316_row9_col1" class="data row9 col1" >90</td>
#       <td id="T_c1316_row9_col2" class="data row9 col2" >3.522222</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c1316_row10_col0" class="data row10 col0" >care_social_care_involvement</td>
#       <td id="T_c1316_row10_col1" class="data row10 col1" >89</td>
#       <td id="T_c1316_row10_col2" class="data row10 col2" >3.561798</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c1316_row11_col0" class="data row11 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_c1316_row11_col1" class="data row11 col1" >87</td>
#       <td id="T_c1316_row11_col2" class="data row11 col2" >3.643678</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c1316_row12_col0" class="data row12 col0" >property_level_infestation</td>
#       <td id="T_c1316_row12_col1" class="data row12 col1" >85</td>
#       <td id="T_c1316_row12_col2" class="data row12 col2" >3.729412</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c1316_row13_col0" class="data row13 col0" >health_substance_misuse</td>
#       <td id="T_c1316_row13_col1" class="data row13 col1" >73</td>
#       <td id="T_c1316_row13_col2" class="data row13 col2" >4.342466</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c1316_row14_col0" class="data row14 col0" >reasonable_adjustments_mental_capacity</td>
#       <td id="T_c1316_row14_col1" class="data row14 col1" >71</td>
#       <td id="T_c1316_row14_col2" class="data row14 col2" >4.464789</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c1316_row15_col0" class="data row15 col0" >care_care_experienced</td>
#       <td id="T_c1316_row15_col1" class="data row15 col1" >71</td>
#       <td id="T_c1316_row15_col2" class="data row15 col2" >4.464789</td>
#     </tr>
#     <tr>
#       <th id="T_c1316_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c1316_row16_col0" class="data row16 col0" >life_events_temporary</td>
#       <td id="T_c1316_row16_col1" class="data row16 col1" >68</td>
#       <td id
# <style type="text/css">
# </style>
# <table id="T_5be01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5be01_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_5be01_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5be01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5be01_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_5be01_row0_col1" class="data row0 col1" >4.91</td>
#     </tr>
#     <tr>
#       <th id="T_5be01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5be01_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_5be01_row1_col1" class="data row1 col1" >7.04</td>
#     </tr>
#     <tr>
#       <th id="T_5be01_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5be01_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_5be01_row2_col1" class="data row2 col1" >0.35</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### PII (Personally-Identifiable Information) Redaction
# Apply PII redaction techniques to the gold standard dataset to ensure privacy and compliance with GDPR before manually annotating.

# %%
def clean_data(df):
    # Anonymise & track names that were replaced
    def anonymize_and_extract_spans(text):
        if not isinstance(text, str):
            return pd.Series({'note_content': text, 'fake_name_spans': []})
            
        # Analyze
        results = analyzer.analyze(text=text, entities=config.redact_entities, language='en')
        
        # Anonymize
        anonymized = anonymizer.anonymize(
            text=text,
            analyzer_results=results, # type: ignore
            operators=operators
        )
        
        fake_spans = []
        for item in anonymized.items:
            if item.entity_type == 'PERSON':
                # Highlight replaced names as fake
                fake_spans.append({
                    'start': item.start,
                    'end': item.end,
                    'text': item.text, 
                    'labels': ['Pseudonym'] 
                })
        
        return pd.Series({
            'note_content': anonymized.text,
            'fake_name_spans': fake_spans
        })

    # Set up engines
    fake = Faker('en')
    Faker.seed(config.random_state)

    analyzer = AnalyzerEngine()
    anonymizer = AnonymizerEngine()

    # Regex matcher for UK postcodes
    uk_postcode_pattern = Pattern(
        name="uk_postcode_regex", 
        regex=r"\b([Gg][Ii][Rr] 0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9][A-Za-z]?))))\s?[0-9][A-Za-z]{2})\b", 
        score=0.85
    )
    uk_postcode_recognizer = PatternRecognizer(
        supported_entity="UK_POSTCODE", 
        patterns=[uk_postcode_pattern]
    )
    analyzer.registry.add_recognizer(uk_postcode_recognizer)

    # Replace names with fake names
    consistent_name_map = {}
    def get_consistent_fake_name(text):
        if text not in consistent_name_map:
            consistent_name_map[text] = fake.name()
        return consistent_name_map[text]

    # Define operator for each entity type
    operators = {
        "PERSON": OperatorConfig("custom", {"lambda": get_consistent_fake_name}),
        "DEFAULT": OperatorConfig("replace") # Automatically replaces with e.g., <PHONE_NUMBER>
    }

    tqdm.pandas() # Enable pandas progress_apply (for progress bar)
    scrubbed_df = df.copy()
    scrubbed_df[['note_content', 'fake_name_spans']] = scrubbed_df['note_content'].progress_apply(anonymize_and_extract_spans)
    return scrubbed_df

# %%
scrubbed_df = clean_data(final_sample)
scrubbed_df.head()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#                                 note_id  \
# 0  0fd02b13-27ed-4c56-9b7e-bf6eb09fc100
# 1  ea4a5bee-00b2-56e1-065b-06eef423ff5f
# 2  b3612383-2e0e-489a-998c-4a45d3879171
# 3  aecaad6d-afa1-610f-4731-645854905741
# 4  33c002f7-37ac-4ae0-9300-beadf1f885eb
#
#                                         note_content       note_category  \
# 0  [Category: estateManagement] incoming call lea...    estateManagement
# 1  [Category: Tenancy Management] tenant is a hoa...  Tenancy Management
# 2  [Category: tenureManagement] letter to residen...    tenureManagement
# 3  [Category: Tenancy Management] see email below...  Tenancy Management
# 4  [Category: estateManagement] email to hygiene ...    estateManagement
#
#    care_care_experienced  care_care_setting  care_has_caring_responsibility  \
# 0                  False              False                           False
# 1                  False              False                           False
# 2                  False              False                           False
# 3                  False              False                           False
# 4                  False              False                           False
#
#    care_social_care_involvement  cautions_asbo_or_injunction_obtained  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    cautions_dangerous_animals  cautions_physical_abuse_or_threat_of  ...  \
# 0                       False                                 False  ...
# 1                       False                                 False  ...
# 2                       False                                 False  ...
# 3                       False                                 False  ...
# 4                       False                                 False  ...
#
#    property_level_property_adapted  property_level_disrepair_damp_mould  \
# 0                            False                                False
# 1                            False                                False
# 2                            False                                False
# 3                             True                                False
# 4                            False                                False
#
#    property_level_infestation  safety_risk_antisocial_behaviour  \
# 0                       False                             False
# 1                       False                              True
# 2                       False                             False
# 3                       False                             False
# 4                       False                             False
#
#    safety_risk_domestic_abuse  safety_risk_firerelated_risks  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                           True
# 3                       False                          False
# 4                       False                          False
#
#    safety_risk_gas_capped  safety_risk_risk_of_exploitation  unflagged  \
# 0                   False                             False       True
# 1                   False                             False      False
# 2                   False                             False      False
# 3                   False                             False      False
# 4                   False                             False      False
#
#                                      fake_name_spans
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'start': 1079, 'end': 1090, 'text': 'Noah Rh...
# 4  [{'start': 607, 'end': 622, 'text': 'Gabrielle...
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Pre-Annotation
# Pre-annotate the category spans, pseudonyms, and role (e.g. tenant, leaseholder). This will help speed up manual annotation.
#
# We use regexes for Additional Need categories and for roles. We use the `fake_name_spans` generated in the previous section to highlight automatically generated pseudonyms as names.

# %%
def generate_label_studio_json(df):
    # Construct regexes for ANs & roles & compile
    person_role_regex = r"(?i)\b(tenant|tenants|leaseholder|leaseholders|resident|residents|child|children|son|daughter|partner|wife|husband|mother|father|caller|applicant|neighbour|neighbor|neighbours|neighbor)\b" # common housing roles
    compiled_role_regex = re.compile(person_role_regex)
    compiled_category_regex = {row.cat_label: re.compile(row.regex) for row in taxonomy_v2.itertuples()} # type: ignore

    # Loop through dataframe rows
    label_studio_tasks = []
    for index, row in tqdm(df.iterrows()):
        note_content = str(row['note_content'])
        note_id = str(row['note_id'])
        
        identified_labels = []
        
        # --- AN Tags ---
        for cat_key, compiled_regex in compiled_category_regex.items():
            for match in compiled_regex.finditer(note_content):
                identified_labels.append({
                    "from_name": "need_labels",  # Needs to match Label Studio XML
                    "to_name": "text",
                    "type": "labels",
                    "value": {
                        "start": match.start(), # Extract the specific span - didn't do with the whole dataset as it is expensive.
                        "end": match.end(),
                        "text": match.group(),
                        "labels": [cat_key]
                    }
                })

        # --- Role Labels ---
        for match in compiled_role_regex.finditer(note_content):
            identified_labels.append({
                "from_name": "entity_labels",  # Needs to match Label Studio XML
                "to_name": "text",
                "type": "labels",
                "value": {
                    "start": match.start(),
                    "end": match.end(),
                    "text": match.group(),
                    "labels": ["Person Role"]
                }
            })

        # --- Fake name Spans (Presidio) ---
        for span in row['fake_name_spans']:
            identified_labels.append({
                "from_name": "entity_labels", # Needs to match Label Studio XML
                "to_name": "text",
                "type": "labels",
                "value": {
                    "start": span['start'],
                    "end": span['end'],
                    "text": span['text'],
                    "labels": span['labels']
                }
            })
        
        # --- Construct label studio task ---
        task = {
            "data": {
                "note_content": note_content,
                "id": note_id
            },
            "predictions": [{
                "model_version": "pre_annotated",
                "score": 1.0,
                "result": identified_labels
            }]
        }
        
        label_studio_tasks.append(task)
    return label_studio_tasks

# %%
label_studio_tasks = generate_label_studio_json(scrubbed_df)
len(label_studio_tasks)
# Out:
# 0it [00:00, ?it/s]
# 2000

# %%
label_studio_tasks[1]
# Out:
# {'data': {'note_content': '[Category: Tenancy Management] tenant is a hoarder and he was advised that he had too many combustible items in his flat.  He promised to clear be4 works commences in his flat. Apprently there he advised that there are some works to be done to his flat.\n\nHowever teh visit was to investigate an anti-social behaviour complaint made against him by Flat 16 but from what i saw he could not be the perp.\n\nTenancy & household Check carried out.',
#   'id': 'ea4a5bee-00b2-56e1-065b-06eef423ff5f'},
#  'predictions': [{'model_version': 'pre_annotated',
#    'score': 1.0,
#    'result': [{'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 43,
#       'end': 50,
#       'text': 'hoarder',
#       'labels': ['cautions_unclean_unsafe_living_environment']}},
#     {'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 43,
#       'end': 50,
#       'text': 'hoarder',
#       'labels': ['housing_conditions_hoarding']}},
#     {'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 295,
#       'end': 306,
#       'text': 'anti-social',
#       'labels': ['safety_risk_antisocial_behaviour']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 31,
#       'end': 37,
#       'text': 'tenant',
#       'labels': ['Person Role']}}]}]}

# %% [markdown]
# ### Export sample set

# %%
# Annotated examples
with open(config.output_gold_standard_json_path, "w") as f:
    json.dump(label_studio_tasks, f, indent=2)

# %%
# Data without annotations
scrubbed_df.to_csv(config.output_gold_standard_csv_path, index=False)
