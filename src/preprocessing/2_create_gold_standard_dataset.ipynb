# %% [markdown]
# # Prepare & Sample Gold Standard Dataset

# %% [markdown]
# ## Overview
# This notebook ingests data from AWS Athena and samples 2000 notes for a 'gold standard' dataset - a subset of our raw data that is human-annotated for subsequent model training.
#
# It goes through several steps of preprocessing:
# - Reshaping through AWS Athena (not run here. See [../reference/additional_needs_reshape.py]()). This combines records from the MMH `notes` table with the `tenure` table to make every note attributed to its relevant tenancy.
#
# - Loading data from our newly made `additional_needs_notes_reshaped` table through Athena. [Link](#acquire-data).
#
# - Acronym Exapansion. Finds commons acronyms in the note. These are then replaced with regexes with their expanded versions (human-verified). [Link](#expand-acronyms).
#
# - Weak labelling using regexes. [Link](#weak-labeling-via-regex).
#
# - Exploratory Data Analysis. [Link](#exploratory-data-analysis).
#
# - Removes low-prevalence labels. [Link](#drop-rare-categories).
#
# - Stratified Sampling using the regexes as a heuristic (45 examples per class - 40*45 = 1800, 1800 + 200 'zero match' classes add to 2000 notes). [Link](#stratified-sample-n2000).
#
# - PII redaction. Strips Personally Identifiable Information (PII) from the gold standard set. Replaces names with autogenerated fake names. [Link](#pii-personally-identifiable-information-redaction).
#
# - Pre-annotation. Uses the regexes to pre-annotate the notes with the correct span (the specific words, e.g. 'resident uses a wheelchair'). [Link](#pre-annotation).
#
# - Exports to CSV and JSON. [Link](#export-sample-set).
#
# **Note: Unredacted data is never persisted on the local device. This is intentional as it prevents data protection issues around storing resident data on local devices, but it means that re-running this file on different days will likely produce different results due to new notes being added to upstream data sources. Keep this in mind as your new reruns could overwrite previous exports.**

# %% [markdown]
# ## Environment Setup

# %%
# Imports
import pandas as pd
import numpy as np
import json
import re
from dataclasses import dataclass

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

from tqdm.notebook import tqdm
from pandarallel import pandarallel

import boto3
import awswrangler as wr

import nltk
from collections import Counter
from nltk.corpus import words

from presidio_analyzer import AnalyzerEngine, PatternRecognizer, Pattern
from presidio_anonymizer import AnonymizerEngine
from presidio_anonymizer.entities import OperatorConfig
from faker import Faker

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent / "src"))

from common.paths import RAW, PROCESSED
from common.graph_helpers import analyze_category_distribution_from_df, plot_cooccurrence_heatmap
from common.logging import setup_logger

# %%
@dataclass
class AwsConfig:
    aws_region = "eu-west-2"
    aws_profile = "data-platform-housing-prod"
    database_name = "housing-refined-zone"
    table_name = "additional_needs_notes_reshaped"

@dataclass
class Config:
    logger = setup_logger('preprocessing.sample_gold_standard')
    AWS = AwsConfig()

    random_state = 42
    target_total = 2000
    target_per_cat = 45

    # Paths
    taxonomy_path_v1 = PROCESSED / "taxonomy_autogen_v1.csv"
    taxonomy_path_v2 = PROCESSED / "taxonomy_autogen_v2.csv"
    output_gold_standard_json_path = PROCESSED / "gold_standard_sample.json"
    output_gold_standard_csv_path = PROCESSED / "gold_standard_sample.csv"
    regex_matches_path = PROCESSED / "full_dataset_regex_matches.csv"

    # PII entites to redact
    redact_entities = [
        "PERSON", 
        "EMAIL_ADDRESS", 
        "PHONE_NUMBER", 
        "DATE_TIME",
        "LOCATION",
        "UK_POSTCODE", 
        "CREDIT_CARD", 
        "IBAN_CODE", 
        "IP_ADDRESS",
        "URL"
    ]

config = Config()

# %%
# Tool setups

# NLTK
nltk.download('words')

# Pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# [nltk_data] Downloading package words to /Users/arawat/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Acquire Data
# Get latest data from AWS Athena.

# %%
def fetch_data_from_athena():
    session = boto3.Session(region_name=config.AWS.aws_region, profile_name=config.AWS.aws_profile)

    sql_query = f''' SELECT DISTINCT note_id, note_content, note_category, note_date
                    FROM "{config.AWS.database_name}".{config.AWS.table_name}
                    WHERE flag_no_matching_target = FALSE
                        AND flag_note_date_parse_failed = FALSE
                        AND flag_is_organisation = FALSE
                        AND flag_inactive = FALSE;
    '''

    return wr.athena.read_sql_query(sql_query, database=config.AWS.database_name, boto3_session=session, ctas_approach=False)

df = fetch_data_from_athena()

# %%
if not df['note_content'].str.startswith('[Category:').all():
    # Prevents this from running twice
    df['note_content'] = "[Category: " + df['note_category'] + "] " + df['note_content']
df.head()
# Out:
#                                 note_id  \
# 0  1e16e387-016b-a2a4-ced6-545940e8ab23
# 1  246ad5cd-e5df-b342-ac8b-83f310f272d6
# 2  2b4dca8c-0aa5-f8e6-a629-d1b0f6cec646
# 3  2f6e8f7a-615c-bd6e-b8b3-28ba2a4c64c3
# 4  3d223195-6f1c-bdf3-96a5-57d3cc3c28f3
#
#                                         note_content       note_category
# 0  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 1  [Category: Tenancy Management] Applicant phone...  Tenancy Management
# 2  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 3  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 4  [Category: Tenancy Management] Call Summary; C...  Tenancy Management

# %% [markdown]
# ## Expand Acronyms
# Discover common acronyms (2-4 letter words that aren't in the English dictionary) and replace them with their expanded forms.

# %%
def get_most_common_acronyms(series: pd.Series, n: int = 100) -> list:
    # Load the standard English dictionary into a lookup set
    english_vocab = set(word.lower() for word in words.words())

    # Find 2-4 letter words (pre-compile for speed)
    acronym_pattern = re.compile(r'\b[a-z]{2,4}\b')
    
    acronym_counter = Counter()

    # Stream and update row-by-row
    for text in series.dropna():
        if isinstance(text, str):
            # Find short words and filter ones that aren't in the dictionary
            short_words = acronym_pattern.findall(text.lower())
            acronyms_only = [word for word in short_words if word not in english_vocab]
            
            # Batch update the counter
            acronym_counter.update(acronyms_only)

    return acronym_counter.most_common(n)

get_most_common_acronyms(df['note_content'], n=100)
# Out:
# [('tnt', 169264),
#  ('has', 164408),
#  ('lh', 61266),
#  ('uk', 60468),
#  ('gov', 50320),
#  ('ms', 40816),
#  ('asb', 39307),
#  ('cb', 31606),
#  ('hb', 29124),
#  ('paid', 22696),
#  ('sc', 18409),
#  ('keys', 15146),
#  ('rcc', 14889),
#  ('cc', 14641),
#  ('hsc', 14404),
#  ('tel', 13849),
#  ('says', 13312),
#  ('ange', 12633),
#  ('dd', 12483),
#  ('doua', 12137),
#  ('com', 12122),
#  ('pls', 10954),
#  ('rtb', 9723),
#  ('auth', 9551),
#  ('eo', 9219),
#  ('cleo', 7622),
#  ('nosp', 7304),
#  ('co', 6583),
#  ('wba', 5917),
#  ('info', 5659),
#  ('uhw', 5388),
#  ('olu', 5181),
#  ('nho', 5053),
#  ('fobs', 4974),
#  ('mpa', 4953),
#  ('bacs', 4900),
#  ('docs', 4742),
#  ('mw', 4636),
#  ('rec', 4582),
#  ('ali', 4552),
#  ('tnts', 4484),
#  ('hh', 4447),
#  ('appt', 4302),
#  ('app', 4206),
#  ('ntq', 4088),
#  ('ncst', 3859),
#  ('itv', 3813),
#  ('uc', 3714),
#  ('acc', 3574),
#  ('ve', 3478),
#  ('emre', 3324),
#  ('gge', 3276),
#  ('mmh', 3216),
#  ('etc', 3053),
#  ('acct', 2935),
#  ('kaur', 2818),
#  ('feb', 2775),
#  ('org', 2726),
#  ('tmo', 2720),
#  ('uht', 2692),
#  ('kofi', 2690),
#  ('www', 2684),
#  ('didn', 2682),
#  ('nb', 2651),
#  ('nom', 2640),
#  ('ahm', 2609),
#  ('uh', 2585),
#  ('vm', 2579),
#  ('recd', 2558),
#  ('asap', 2513),
#  ('hasn', 2403),
#  ('nov', 2310),
#  ('msg', 2268),
#  ('cust', 2260),
#  ('oct', 2240),
#  ('dec', 2226),
#  ('ac', 2225),
#  ('lbh', 2097),
#  ('pm', 2031),
#  ('aug', 1859),
#  ('cst', 1745),
#  ('ot', 1725),
#  ('ll', 1680),
#  ('dv', 1677),
#  ('elli', 1643),
#  ('pd', 1639),
#  ('cert', 1639),
#  ('dlo', 1567),
#  ('gets', 1557),
#  ('cctv', 1551),
#  ('cs', 1518),
#  ('rd', 1486),
#  ('ct', 1458),
#  ('gp', 1457),
#  ('mex', 1438),
#  ('wasn', 1421),
#  ('ctax', 1399),
#  ('nhs', 1365),
#  ('uju', 1357),
#  ('lr', 1323)]

# %% [markdown]
# ### Replace acronyms
# We looked at the common acronyms from the cell above and constructed a *normalisation dictionary*.

# %%
abbreviation_mapping = {
    # Hackney terms
    r'\bhsc\b': 'Hackney Service Centre',
    r'\bmmh\b': 'Manage My Home',
    r'\blbh\b': 'London Borough of Hackney',
    r'\brcc\b': 'Repairs Contact Centre',

    # Housing terms
    r'\btnt\b': 'tenant',
    r'\bclt\b': 'client',
    r'\btnts\b': 'tenants',
    r'\bl/h\b': 'leaseholder',
    r'\bh/o\b': 'housing officer',
    r'\btmo\b': 'Tenant Management Organisation',
    r'\bnho\b': 'neighbourhood housing officer',
    r'\bahm\b': 'area housing manager',
    r'\bhb\b': 'housing benefit',
    r'\bnosp\b': 'Notice of Seeking Possession',
    r'\bntq\b': 'Notice to Quit',
    r'\brtb\b': 'Right to Buy',
    r'\buc\b': 'Universal Credit',
    r'\basb\b': 'anti-social behaviour',
    r'\bdv\b': 'domestic violence',
    r'\bda\b': 'domestic abuse',

    # General terms
    r'\btel\b': 'telephone',
    r'\bdocs\b': 'documents',
    r'\bappt\b': 'appointment',
    r'\bacct\b': 'account',
    r'\bbacs\b': 'bank transfer',
    r'\binfo\b': 'information',
    r'\borg\b': 'organisation',
    r'\bsms\b': 'text message',
    r'\bmsg\b': 'message',
    r'\bcctv\b': 'camera',
    r'\bgp\b': 'general practitioner',
    r'\bpls\b': 'please',
    r'\brecd\b': 'received',
    r'\basap\b': 'as soon as possible',
    r'\bpls\b': 'please',
    r'\bcert\b': 'certificate',
    r'\bvm\b': 'voicemail',
}

# %%
acronym_substitution_patterns = [(re.compile(p, re.IGNORECASE), r) for p, r in abbreviation_mapping.items()]

def normalize_acronyms(text):
    if pd.isna(text):
        return text
    for pattern, replacement in acronym_substitution_patterns:
        text = pattern.sub(replacement, text)
    return text

df['note_content'] = df['note_content'].parallel_apply(normalize_acronyms)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=87277), Label(value='0 / 87277')))…

# %% [markdown]
# ## Weak Labeling via Regex
# Apply the regex patterns from the taxonomy csv to assign 'weak labels' to the dataset.

# %%
taxonomy = pd.read_csv(config.taxonomy_path_v1)

# %%
category_regex_patterns = [(row.cat_label, re.compile(row.regex, re.IGNORECASE)) for row in taxonomy.itertuples()] # type: ignore

def flag_category_matches(series):
    """
    Apply all category regexes to a pandas Series of texts.
    Returns a DataFrame of boolean flags.
    """
    def apply_all_categories(text):
        return {label: bool(pattern.search(text)) for label, pattern in category_regex_patterns}

    results = series.fillna('').parallel_apply(apply_all_categories)
    return pd.DataFrame(results.tolist())

df = df.join(flag_category_matches(df['note_content']))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=87277), Label(value='0 / 87277')))…

# %%
df.head()
# Out:
#                                 note_id  \
# 0  1e16e387-016b-a2a4-ced6-545940e8ab23
# 1  246ad5cd-e5df-b342-ac8b-83f310f272d6
# 2  2b4dca8c-0aa5-f8e6-a629-d1b0f6cec646
# 3  2f6e8f7a-615c-bd6e-b8b3-28ba2a4c64c3
# 4  3d223195-6f1c-bdf3-96a5-57d3cc3c28f3
#
#                                         note_content       note_category  \
# 0  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 1  [Category: Tenancy Management] Applicant phone...  Tenancy Management
# 2  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 3  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
# 4  [Category: Tenancy Management] Call Summary; C...  Tenancy Management
#
#    care_care_experienced  care_care_setting  care_has_caring_responsibility  \
# 0                  False              False                           False
# 1                  False              False                           False
# 2                  False              False                           False
# 3                  False              False                           False
# 4                  False              False                           False
#
#    care_social_care_involvement  cautions_asbo_or_injunction_obtained  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    cautions_dangerous_animals  cautions_visiting_requirements  ...  \
# 0                       False                           False  ...
# 1                       False                           False  ...
# 2                       False                           False  ...
# 3                       False                           False  ...
# 4                       False                           False  ...
#
#    mobility_service_need  property_level_property_adapted  \
# 0                  False                            False
# 1                  False                            False
# 2                  False                            False
# 3                  False                            False
# 4                  False                            False
#
#    property_level_disrepair_damp_mould  property_level_infestation  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
#
#    safety_risk_antisocial_behaviour  safety_risk_domestic_abuse  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
#
#    safety_risk_firerelated_risks  safety_risk_gas_capped  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
#
#    safety_risk_risk_of_exploitation  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    safety_risk_gang_activity_serious_youth_violence
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
# [5 rows x 45 columns]

# %%
# Save out (without sensitive data)
df.drop('note_content', axis=1).to_csv(config.regex_matches_path, index=False)

# %% [markdown]
# ## Exploratory Data Analysis
# Analyze the distribution of the weak labels to understand class imbalances and inform stratified sampling. Analyse which labels co-occur.

# %%
def display_note_lengths_hist(df):
    # Length of notes in words (histogram)
    note_length_words = df['note_content'].fillna('').str.split().apply(len)
    plot_lengths = note_length_words[note_length_words <= 120] # Cut off outliers to fix graph size (over 95th percentile)

    # Histogram of note lengths
    counts, bins = np.histogram(plot_lengths, bins=24) # Bin size of 5

    # Convert bin edges into bar positions and widths
    bin_centres = (bins[:-1] + bins[1:]) / 2
    bin_widths = np.diff(bins)

    plt.bar(bin_centres, counts, width=bin_widths, edgecolor='black')

    # Mean + SD + 95th percentile
    mean_val = note_length_words.mean()
    standard_dev = note_length_words.std()
    p = np.percentile(note_length_words, 95)

    plt.axvline(mean_val, color='black', linestyle='--')
    plt.text(mean_val, plt.ylim()[1] * 0.9, f'Mean: {mean_val:.0f} words')

    plt.xlabel('Number of Words')
    plt.ylabel('Frequency')
    plt.title('Distribution of Note Lengths (in Words)')
    plt.show()

    print(f'Mean: {mean_val}, Standard Deviation: {standard_dev}, 95th percentile: {p}')

    return bin_centres, counts


bin_centres, counts = display_note_lengths_hist(df)
print(pd.DataFrame(zip(bin_centres, counts), columns=['bin', 'count']))
# Out:
# Mean: 35.92981501320516, Standard Deviation: 36.30183131793461, 95th percentile: 106.0
#       bin   count
# 0     2.5    1546
# 1     7.5   85451
# 2    12.5   62349
# 3    17.5   80288
# 4    22.5  129067
# 5    27.5   71819
# 6    32.5   44723
# 7    37.5   34359
# 8    42.5   27945
# 9    47.5   22846
# 10   52.5   18729
# 11   57.5   15222
# 12   62.5   12733
# 13   67.5   10883
# 14   72.5    9272
# 15   77.5    7917
# 16   82.5    6832
# 17   87.5    6091
# 18   92.5    5442
# 19   97.5    4539
# 20  102.5    4013
# 21  107.5    3318
# 22  112.5    2944
# 23  117.5    3112

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(df.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_98147_row0_col2, #T_98147_row1_col2, #T_98147_row2_col2, #T_98147_row3_col2, #T_98147_row4_col2, #T_98147_row5_col2, #T_98147_row6_col2, #T_98147_row7_col2, #T_98147_row8_col2, #T_98147_row9_col2, #T_98147_row10_col2, #T_98147_row11_col2, #T_98147_row12_col2, #T_98147_row13_col2, #T_98147_row14_col2, #T_98147_row15_col2, #T_98147_row16_col2, #T_98147_row17_col2, #T_98147_row18_col2, #T_98147_row19_col2, #T_98147_row20_col2, #T_98147_row21_col2, #T_98147_row22_col2, #T_98147_row23_col2, #T_98147_row24_col2, #T_98147_row25_col2, #T_98147_row26_col2, #T_98147_row27_col2, #T_98147_row28_col2, #T_98147_row29_col2, #T_98147_row30_col2, #T_98147_row31_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_98147_row32_col2, #T_98147_row33_col2, #T_98147_row34_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_98147_row35_col2, #T_98147_row36_col2, #T_98147_row37_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_98147_row38_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_98147_row39_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_98147_row40_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_98147_row41_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98147">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98147_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_98147_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_98147_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98147_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98147_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_98147_row0_col1" class="data row0 col1" >56375</td>
#       <td id="T_98147_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98147_row1_col0" class="data row1 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_98147_row1_col1" class="data row1 col1" >32477</td>
#       <td id="T_98147_row1_col2" class="data row1 col2" >1.735844</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98147_row2_col0" class="data row2 col0" >property_level_infestation</td>
#       <td id="T_98147_row2_col1" class="data row2 col1" >5415</td>
#       <td id="T_98147_row2_col2" class="data row2 col2" >10.410896</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98147_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_98147_row3_col1" class="data row3 col1" >4794</td>
#       <td id="T_98147_row3_col2" class="data row3 col2" >11.759491</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98147_row4_col0" class="data row4 col0" >life_events_temporary</td>
#       <td id="T_98147_row4_col1" class="data row4 col1" >4196</td>
#       <td id="T_98147_row4_col2" class="data row4 col2" >13.435415</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98147_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_98147_row5_col1" class="data row5 col1" >3610</td>
#       <td id="T_98147_row5_col2" class="data row5 col2" >15.616343</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98147_row6_col0" class="data row6 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_98147_row6_col1" class="data row6 col1" >3116</td>
#       <td id="T_98147_row6_col2" class="data row6 col2" >18.092105</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98147_row7_col0" class="data row7 col0" >health_substance_misuse</td>
#       <td id="T_98147_row7_col1" class="data row7 col1" >2852</td>
#       <td id="T_98147_row7_col2" class="data row7 col2" >19.766830</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98147_row8_col0" class="data row8 col0" >care_social_care_involvement</td>
#       <td id="T_98147_row8_col1" class="data row8 col1" >1844</td>
#       <td id="T_98147_row8_col2" class="data row8 col2" >30.572126</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98147_row9_col0" class="data row9 col0" >safety_risk_firerelated_risks</td>
#       <td id="T_98147_row9_col1" class="data row9 col1" >1748</td>
#       <td id="T_98147_row9_col2" class="data row9 col2" >32.251144</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98147_row10_col0" class="data row10 col0" >reasonable_adjustments_mental_capacity</td>
#       <td id="T_98147_row10_col1" class="data row10 col1" >1728</td>
#       <td id="T_98147_row10_col2" class="data row10 col2" >32.624421</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98147_row11_col0" class="data row11 col0" >health_care_setting</td>
#       <td id="T_98147_row11_col1" class="data row11 col1" >1717</td>
#       <td id="T_98147_row11_col2" class="data row11 col2" >32.833430</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98147_row12_col0" class="data row12 col0" >cautions_dangerous_animals</td>
#       <td id="T_98147_row12_col1" class="data row12 col1" >1565</td>
#       <td id="T_98147_row12_col2" class="data row12 col2" >36.022364</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98147_row13_col0" class="data row13 col0" >life_events_life_events</td>
#       <td id="T_98147_row13_col1" class="data row13 col1" >1218</td>
#       <td id="T_98147_row13_col2" class="data row13 col2" >46.284893</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98147_row14_col0" class="data row14 col0" >housing_conditions_hoarding</td>
#       <td id="T_98147_row14_col1" class="data row14 col1" >1011</td>
#       <td id="T_98147_row14_col2" class="data row14 col2" >55.761622</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98147_row15_col0" class="data row15 col0" >health_neurodiversity_learning_disability</td>
#       <td id="T_98147_row15_col1" class="data row15 col1" >888</td>
#       <td id="T_98147_row15_col2" class="data row15 col2" >63.485360</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98147_row16_col0" class="data row16 col0" >mobility_mobility_physical</td>
#       <td id="T_98147_row16_col1" class="data row16 col1" >765</td>
#       <td id="T_98147_row16_col2" class="data row16 col2" >73.692810</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98147_row17_col0" class="data row17 col0" >disability_requires_adapted_property</td>
#       <td id="T_98147_row17_col1" class="data row17 col1" >752</td>
#       <td id="T_98147_row17_col2" class="data row17 col2" >74.966755</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_98147_row18_col0" class="data row18 col0" >property_level_property_adapted</td>
#       <td id="T_98147_row18_col1" class="data row18 col1" >749</td>
#       <td id="T_98147_row18_col2" class="data row18 col2" >75.267023</td>
#     </tr>
#     <tr>
#       <th id="T_98147_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_98147_row19_col0" class="data row19 col0" >c
# <style type="text/css">
# </style>
# <table id="T_47cac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47cac_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_47cac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47cac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47cac_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_47cac_row0_col1" class="data row0 col1" >1637.66</td>
#     </tr>
#     <tr>
#       <th id="T_47cac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47cac_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_47cac_row1_col1" class="data row1 col1" >56375.00</td>
#     </tr>
#     <tr>
#       <th id="T_47cac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47cac_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_47cac_row2_col1" class="data row2 col1" >5.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Number of notes that have at least one category match
bool_cols = df.select_dtypes(include=["bool"])
true_row_count = bool_cols.any(axis=1).sum()
print("%.2f" % (true_row_count/len(df) * 100) + "%")
# Out:
# 16.71%

# %%
plot_cooccurrence_heatmap(df, taxonomy)
# Out:
# <Axes: title={'center': 'Label Co-occurrence'}, xlabel='Categories', ylabel='Categories'>

# %% [markdown]
# ### Drop rare categories
# Based on the EDA, drop categories to address class imbalance and ensure sufficient representation for sampling. Dropped categories will only rely on regex instead.

# %%
df_v2 = df.copy()
taxonomy_v2 = taxonomy.copy()

dropped_categories = [
    'life_events_identity', # Only one hit. Should drop.
    'cautions_visiting_requirements', # 12 hits
    'safety_risk_gang_activity_serious_youth_violence', # 33 hits
]

df_v2.drop(columns=dropped_categories, inplace=True)
mask = taxonomy_v2['cat_label'].isin(dropped_categories)
taxonomy_v2 = taxonomy_v2[~mask].reset_index(drop=True)
taxonomy_v2.to_csv(config.taxonomy_path_v2, index=False)

taxonomy_v2.head()
# Out:
#   high_level_category         category_description  \
# 0                Care             Care experienced
# 1                Care                 Care setting
# 2                Care    Has caring responsibility
# 3                Care      Social care involvement
# 4            Cautions  ASBO or injunction obtained
#
#                                        values_hint  \
# 0   ['Care leaver', 'Care experienced (under 25)']
# 1                      ['Fostered', 'Social care']
# 2                           ['Formal', 'Informal']
# 3  ['Adult Social Care', "Children's Social Care"]
# 4                           ['ASBO', 'Injunction']
#
#                               cat_label  \
# 0                 care_care_experienced
# 1                     care_care_setting
# 2        care_has_caring_responsibility
# 3          care_social_care_involvement
# 4  cautions_asbo_or_injunction_obtained
#
#                                                regex
# 0  \bcare experienced\b|\bcare leaver\b|\baged ou...
# 1  \bfostered\b|\bfoster care\b|\bfoster placemen...
# 2  \bformal carer\b|\bregistered carer\b|\bcarer....
# 3  \bsocial care\b|\bcare package\b|\bcare plan\b...
# 4  \bASBO\b|\binjunction\b|\bcivil injunction\b|\...

# %%
del df # memory saving

# %% [markdown]
# ### Compare class imbalance
# Compare the class imbalance before and after combining/dropping categories to assess the impact on the dataset.

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(df_v2.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy_v2, log_scale=False)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_8aef2_row0_col2, #T_8aef2_row1_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_8aef2_row2_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_8aef2_row3_col2, #T_8aef2_row4_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_8aef2_row5_col2, #T_8aef2_row6_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_8aef2_row7_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_8aef2_row8_col2, #T_8aef2_row9_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_8aef2_row10_col2, #T_8aef2_row11_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_8aef2_row12_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_8aef2_row13_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_8aef2_row14_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_8aef2_row15_col2 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_8aef2_row16_col2 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_8aef2_row17_col2, #T_8aef2_row18_col2, #T_8aef2_row19_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_8aef2_row20_col2 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_8aef2_row21_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_8aef2_row22_col2 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_8aef2_row23_col2 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_8aef2_row24_col2, #T_8aef2_row25_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_8aef2_row26_col2 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_8aef2_row27_col2 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_8aef2_row28_col2 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_8aef2_row29_col2 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_8aef2_row30_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_8aef2_row31_col2 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_8aef2_row32_col2 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_8aef2_row33_col2 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_8aef2_row34_col2 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_8aef2_row35_col2 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_8aef2_row36_col2 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_8aef2_row37_col2 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_8aef2_row38_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8aef2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8aef2_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_8aef2_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_8aef2_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aef2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8aef2_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_8aef2_row0_col1" class="data row0 col1" >56375</td>
#       <td id="T_8aef2_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8aef2_row1_col0" class="data row1 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_8aef2_row1_col1" class="data row1 col1" >32477</td>
#       <td id="T_8aef2_row1_col2" class="data row1 col2" >1.735844</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8aef2_row2_col0" class="data row2 col0" >property_level_infestation</td>
#       <td id="T_8aef2_row2_col1" class="data row2 col1" >5415</td>
#       <td id="T_8aef2_row2_col2" class="data row2 col2" >10.410896</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8aef2_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_8aef2_row3_col1" class="data row3 col1" >4794</td>
#       <td id="T_8aef2_row3_col2" class="data row3 col2" >11.759491</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8aef2_row4_col0" class="data row4 col0" >life_events_temporary</td>
#       <td id="T_8aef2_row4_col1" class="data row4 col1" >4196</td>
#       <td id="T_8aef2_row4_col2" class="data row4 col2" >13.435415</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8aef2_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_8aef2_row5_col1" class="data row5 col1" >3610</td>
#       <td id="T_8aef2_row5_col2" class="data row5 col2" >15.616343</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8aef2_row6_col0" class="data row6 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_8aef2_row6_col1" class="data row6 col1" >3116</td>
#       <td id="T_8aef2_row6_col2" class="data row6 col2" >18.092105</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8aef2_row7_col0" class="data row7 col0" >health_substance_misuse</td>
#       <td id="T_8aef2_row7_col1" class="data row7 col1" >2852</td>
#       <td id="T_8aef2_row7_col2" class="data row7 col2" >19.766830</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8aef2_row8_col0" class="data row8 col0" >care_social_care_involvement</td>
#       <td id="T_8aef2_row8_col1" class="data row8 col1" >1844</td>
#       <td id="T_8aef2_row8_col2" class="data row8 col2" >30.572126</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8aef2_row9_col0" class="data row9 col0" >safety_risk_firerelated_risks</td>
#       <td id="T_8aef2_row9_col1" class="data row9 col1" >1748</td>
#       <td id="T_8aef2_row9_col2" class="data row9 col2" >32.251144</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8aef2_row10_col0" class="data row10 col0" >reasonable_adjustments_mental_capacity</td>
#       <td id="T_8aef2_row10_col1" class="data row10 col1" >1728</td>
#       <td id="T_8aef2_row10_col2" class="data row10 col2" >32.624421</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8aef2_row11_col0" class="data row11 col0" >health_care_setting</td>
#       <td id="T_8aef2_row11_col1" class="data row11 col1" >1717</td>
#       <td id="T_8aef2_row11_col2" class="data row11 col2" >32.833430</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8aef2_row12_col0" class="data row12 col0" >cautions_dangerous_animals</td>
#       <td id="T_8aef2_row12_col1" class="data row12 col1" >1565</td>
#       <td id="T_8aef2_row12_col2" class="data row12 col2" >36.022364</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8aef2_row13_col0" class="data row13 col0" >life_events_life_events</td>
#       <td id="T_8aef2_row13_col1" class="data row13 col1" >1218</td>
#       <td id="T_8aef2_row13_col2" class="data row13 col2" >46.284893</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8aef2_row14_col0" class="data row14 col0" >housing_conditions_hoarding</td>
#       <td id="T_8aef2_row14_col1" class="data row14 col1" >1011</td>
#       <td id="T_8aef2_row14_col2" class="data row14 col2" >55.761622</td>
#     </tr>
#     <tr>
#       <th id="T_8aef2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8aef2_row15_col0" class="data row15 col0" >health_neurodiversity_learning_disability</td>
#       <td id="T_8aef2_row15_col1" class="data row15 col1" >888</td>
#       <td id="T_8aef2_row15_col2" class="data row15 col2" >63.485360</td>
#     </tr>
#     <tr>
# <style type="text/css">
# </style>
# <table id="T_82383">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82383_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_82383_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82383_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82383_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_82383_row0_col1" class="data row0 col1" >153.86</td>
#     </tr>
#     <tr>
#       <th id="T_82383_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82383_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_82383_row1_col1" class="data row1 col1" >894.84</td>
#     </tr>
#     <tr>
#       <th id="T_82383_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82383_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_82383_row2_col1" class="data row2 col1" >1.28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Construct Gold Standard Set
# Uses *iterative random sampling*, which is a common technique to perform stratified sampling on a multi-label dataset. We start by choosing n=45 examples of the least prevalent class and then continue with the rest of the labels, removing examples that have already been sampled. This helps to balance the dataset where examples can have multiple labels.

# %% [markdown]
# ### Stratified Sample (n=2000)
# Perform stratified sampling based on the weak labels to create a balanced gold standard dataset of 2000 records for manual annotation.

# %%
# Get unflagged records - zero category matches.
df_v2['unflagged'] = ~df_v2[taxonomy_v2['cat_label']].any(axis=1)
df_v2['unflagged'].value_counts()
# Out:
# unflagged
# True     581589
# False    116623
# Name: count, dtype: int64

# %%
def sample_gold_standard(df, taxonomy):
    sampled_data = []
    sampled_ids = set()

    # Sample categories by least prevalent (up to config.target_per_cat)
    category_counts = df[taxonomy['cat_label']].sum().sort_values(ascending=True)
    for cat in category_counts.index:
        pool = df[df[cat] & ~df['note_id'].isin(sampled_ids)] # In the category and not already sampled
        n = min(len(pool), config.target_per_cat)
        if n > 0:
            sample = pool.sample(n=n, random_state=config.random_state) # Random sample
            sampled_data.append(sample)
            sampled_ids.update(sample['note_id'].tolist())

    # Sample unflagged (non-category matches) records
    pool = df[df['unflagged'] & ~df['note_id'].isin(sampled_ids)]
    n = min(len(pool), config.target_total - len(sampled_ids))
    if n > 0:
        sample = pool.sample(n=n, random_state=config.random_state)
        sampled_data.append(sample)
        sampled_ids.update(sample['note_id'].tolist())

    # Combine and shuffle
    return pd.concat(sampled_data).sample(frac=1, random_state=config.random_state).reset_index(drop=True)

# %%
final_sample = sample_gold_standard(df_v2, taxonomy_v2)
final_sample.drop(columns=['note_id', 'note_content', 'note_category']).sum().sort_values()
# Out:
# cautions_physical_abuse_or_threat_of           45
# health_terminally_ill                          46
# health_medical_condition                       46
# safety_risk_risk_of_exploitation               47
# care_care_setting                              48
# communication_digital_exclusion                48
# health_medical_life_sustaining                 48
# health_breathing_respiratory_problems          48
# safety_risk_gas_capped                         49
# cautions_asbo_or_injunction_obtained           51
# reasonable_adjustments_communication_needs     51
# housing_conditions_utilities                   51
# life_events_social_isolation                   51
# cautions_unclean_unsafe_living_environment     52
# health_cognitive_impairment                    54
# communication_fluency_in_english               55
# mobility_service_need                          56
# health_neurodiversity_learning_disability      56
# life_events_life_events                        60
# safety_risk_firerelated_risks                  61
# care_has_caring_responsibility                 63
# cautions_dangerous_animals                     64
# reasonable_adjustments_mental_capacity         66
# care_care_experienced                          71
# disability_sensory                             72
# health_substance_misuse                        73
# life_events_temporary                          74
# safety_risk_domestic_abuse                     77
# housing_conditions_hoarding                    87
# property_level_infestation                     87
# care_social_care_involvement                   94
# mobility_mobility_physical                     96
# disability_requires_adapted_property           96
# property_level_property_adapted                96
# cautions_verbal_abuse_or_threat_of             98
# health_care_setting                           104
# health_mental_health                          141
# safety_risk_antisocial_behaviour              193
# unflagged                                     245
# property_level_disrepair_damp_mould           330
# dtype: int64

# %%
del df_v2 # Memory saving

# %% [markdown]
# ### Compare class imbalance
# Compare the class imbalance in the gold standard set to the original dataset to evaluate the effectiveness of the sampling strategy.

# %%
(irlbl_df, summary, ax) = analyze_category_distribution_from_df(final_sample.drop(columns=['note_id', 'note_content', 'note_category']), taxonomy_v2, log_scale=False)
display(irlbl_df.style.background_gradient(cmap='Reds', subset=['IRLbl']))
display(summary)
# Out:
# <style type="text/css">
# #T_786f5_row0_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_786f5_row1_col2 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_786f5_row2_col2 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_786f5_row3_col2 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_786f5_row4_col2 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_786f5_row5_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_786f5_row6_col2, #T_786f5_row7_col2, #T_786f5_row8_col2 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_786f5_row9_col2 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_786f5_row10_col2, #T_786f5_row11_col2 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_786f5_row12_col2 {
#   background-color: #f96346;
#   color: #f1f1f1;
# }
# #T_786f5_row13_col2 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_786f5_row14_col2 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_786f5_row15_col2 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_786f5_row16_col2 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_786f5_row17_col2 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_786f5_row18_col2 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_786f5_row19_col2 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_786f5_row20_col2 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_786f5_row21_col2 {
#   background-color: #d72322;
#   color: #f1f1f1;
# }
# #T_786f5_row22_col2, #T_786f5_row23_col2 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_786f5_row24_col2 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_786f5_row25_col2 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_786f5_row26_col2 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_786f5_row27_col2, #T_786f5_row28_col2, #T_786f5_row29_col2, #T_786f5_row30_col2 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_786f5_row31_col2 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_786f5_row32_col2, #T_786f5_row33_col2, #T_786f5_row34_col2, #T_786f5_row35_col2 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_786f5_row36_col2 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_786f5_row37_col2, #T_786f5_row38_col2 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_786f5_row39_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_786f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_786f5_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_786f5_level0_col1" class="col_heading level0 col1" >frequency</th>
#       <th id="T_786f5_level0_col2" class="col_heading level0 col2" >IRLbl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_786f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_786f5_row0_col0" class="data row0 col0" >property_level_disrepair_damp_mould</td>
#       <td id="T_786f5_row0_col1" class="data row0 col1" >330</td>
#       <td id="T_786f5_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_786f5_row1_col0" class="data row1 col0" >unflagged</td>
#       <td id="T_786f5_row1_col1" class="data row1 col1" >245</td>
#       <td id="T_786f5_row1_col2" class="data row1 col2" >1.346939</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_786f5_row2_col0" class="data row2 col0" >safety_risk_antisocial_behaviour</td>
#       <td id="T_786f5_row2_col1" class="data row2 col1" >193</td>
#       <td id="T_786f5_row2_col2" class="data row2 col2" >1.709845</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_786f5_row3_col0" class="data row3 col0" >health_mental_health</td>
#       <td id="T_786f5_row3_col1" class="data row3 col1" >141</td>
#       <td id="T_786f5_row3_col2" class="data row3 col2" >2.340426</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_786f5_row4_col0" class="data row4 col0" >health_care_setting</td>
#       <td id="T_786f5_row4_col1" class="data row4 col1" >104</td>
#       <td id="T_786f5_row4_col2" class="data row4 col2" >3.173077</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_786f5_row5_col0" class="data row5 col0" >cautions_verbal_abuse_or_threat_of</td>
#       <td id="T_786f5_row5_col1" class="data row5 col1" >98</td>
#       <td id="T_786f5_row5_col2" class="data row5 col2" >3.367347</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_786f5_row6_col0" class="data row6 col0" >property_level_property_adapted</td>
#       <td id="T_786f5_row6_col1" class="data row6 col1" >96</td>
#       <td id="T_786f5_row6_col2" class="data row6 col2" >3.437500</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_786f5_row7_col0" class="data row7 col0" >mobility_mobility_physical</td>
#       <td id="T_786f5_row7_col1" class="data row7 col1" >96</td>
#       <td id="T_786f5_row7_col2" class="data row7 col2" >3.437500</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_786f5_row8_col0" class="data row8 col0" >disability_requires_adapted_property</td>
#       <td id="T_786f5_row8_col1" class="data row8 col1" >96</td>
#       <td id="T_786f5_row8_col2" class="data row8 col2" >3.437500</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_786f5_row9_col0" class="data row9 col0" >care_social_care_involvement</td>
#       <td id="T_786f5_row9_col1" class="data row9 col1" >94</td>
#       <td id="T_786f5_row9_col2" class="data row9 col2" >3.510638</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_786f5_row10_col0" class="data row10 col0" >property_level_infestation</td>
#       <td id="T_786f5_row10_col1" class="data row10 col1" >87</td>
#       <td id="T_786f5_row10_col2" class="data row10 col2" >3.793103</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_786f5_row11_col0" class="data row11 col0" >housing_conditions_hoarding</td>
#       <td id="T_786f5_row11_col1" class="data row11 col1" >87</td>
#       <td id="T_786f5_row11_col2" class="data row11 col2" >3.793103</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_786f5_row12_col0" class="data row12 col0" >safety_risk_domestic_abuse</td>
#       <td id="T_786f5_row12_col1" class="data row12 col1" >77</td>
#       <td id="T_786f5_row12_col2" class="data row12 col2" >4.285714</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_786f5_row13_col0" class="data row13 col0" >life_events_temporary</td>
#       <td id="T_786f5_row13_col1" class="data row13 col1" >74</td>
#       <td id="T_786f5_row13_col2" class="data row13 col2" >4.459459</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_786f5_row14_col0" class="data row14 col0" >health_substance_misuse</td>
#       <td id="T_786f5_row14_col1" class="data row14 col1" >73</td>
#       <td id="T_786f5_row14_col2" class="data row14 col2" >4.520548</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_786f5_row15_col0" class="data row15 col0" >disability_sensory</td>
#       <td id="T_786f5_row15_col1" class="data row15 col1" >72</td>
#       <td id="T_786f5_row15_col2" class="data row15 col2" >4.583333</td>
#     </tr>
#     <tr>
#       <th id="T_786f5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_786f5_row16_col0" class="data row16 col0" >care_care_experienced</td>
# <style type="text/css">
# </style>
# <table id="T_6bc1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bc1a_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_6bc1a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bc1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bc1a_row0_col0" class="data row0 col0" >MeanIR</td>
#       <td id="T_6bc1a_row0_col1" class="data row0 col1" >5.06</td>
#     </tr>
#     <tr>
#       <th id="T_6bc1a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6bc1a_row1_col0" class="data row1 col0" >MaxIR</td>
#       <td id="T_6bc1a_row1_col1" class="data row1 col1" >7.33</td>
#     </tr>
#     <tr>
#       <th id="T_6bc1a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6bc1a_row2_col0" class="data row2 col0" >CVIR</td>
#       <td id="T_6bc1a_row2_col1" class="data row2 col1" >0.34</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### PII (Personally-Identifiable Information) Redaction
# Apply PII redaction techniques to the gold standard dataset to ensure privacy and compliance with GDPR before manually annotating.

# %%
def clean_data(df):
    # Anonymise & track names that were replaced
    def anonymize_and_extract_spans(text):
        if not isinstance(text, str):
            return pd.Series({'note_content': text, 'fake_name_spans': []})
            
        # Analyze
        results = analyzer.analyze(text=text, entities=config.redact_entities, language='en')
        
        # Anonymize
        anonymized = anonymizer.anonymize(
            text=text,
            analyzer_results=results, # type: ignore
            operators=operators
        )
        
        fake_spans = []
        for item in anonymized.items:
            if item.entity_type == 'PERSON':
                # Highlight replaced names as fake
                fake_spans.append({
                    'start': item.start,
                    'end': item.end,
                    'text': item.text, 
                    'labels': ['Pseudonym'] 
                })
        
        return pd.Series({
            'note_content': anonymized.text,
            'fake_name_spans': fake_spans
        })

    # Set up engines
    fake = Faker('en')
    Faker.seed(config.random_state)

    analyzer = AnalyzerEngine()
    anonymizer = AnonymizerEngine()

    # Regex matcher for UK postcodes
    uk_postcode_pattern = Pattern(
        name="uk_postcode_regex", 
        regex=r"\b([Gg][Ii][Rr] 0[Aa]{2})|((([A-Za-z][0-9]{1,2})|(([A-Za-z][A-Ha-hJ-Yj-y][0-9]{1,2})|(([A-Za-z][0-9][A-Za-z])|([A-Za-z][A-Ha-hJ-Yj-y][0-9][A-Za-z]?))))\s?[0-9][A-Za-z]{2})\b", 
        score=0.85
    )
    uk_postcode_recognizer = PatternRecognizer(
        supported_entity="UK_POSTCODE", 
        patterns=[uk_postcode_pattern]
    )
    analyzer.registry.add_recognizer(uk_postcode_recognizer)

    # Replace names with fake names
    consistent_name_map = {}
    def get_consistent_fake_name(text):
        if text not in consistent_name_map:
            consistent_name_map[text] = fake.name()
        return consistent_name_map[text]

    # Define operator for each entity type
    operators = {
        "PERSON": OperatorConfig("custom", {"lambda": get_consistent_fake_name}),
        "DEFAULT": OperatorConfig("replace") # Automatically replaces with e.g., <PHONE_NUMBER>
    }

    tqdm.pandas() # Enable pandas progress_apply (for progress bar)
    scrubbed_df = df.copy()
    scrubbed_df[['note_content', 'fake_name_spans']] = scrubbed_df['note_content'].progress_apply(anonymize_and_extract_spans)
    return scrubbed_df

# %%
scrubbed_df = clean_data(final_sample)
scrubbed_df.head()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 scrubbed_df = clean_data(final_sample)
#       2 scrubbed_df.head()
#
# Cell In[27], line 67, in clean_data(df)
#      63     }
#      64
#      65     tqdm.pandas() # Enable pandas progress_apply (for progress bar)
#      66     scrubbed_df = df.copy()
# ---> 67     scrubbed_df[['note_content', 'fake_name_spans']] = scrubbed_df['note_content'].progress_apply(anonymize_and_extract_spans)
#      68     return scrubbed_df
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/tqdm/std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:1753, in ArrowExtensionArray.map(self, mapper, na_action)
#    1747     return map_array(self.to_numpy(), mapper, na_action=na_action)
#    1748 else:
#    1749     # For "mM" cases, the super() method passes `self` without the
#    1750     #  to_numpy call, which inside map_array casts to ndarray[object].
#    1751     #  Without the to_numpy() call, NA is preserved instead of changed
#    1752     #  to None.
# -> 1753     return super().map(mapper, na_action)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/arrays/base.py:2745, in ExtensionArray.map(self, mapper, na_action)
#    2725 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2726     """
#    2727     Map values using an input mapping or function.
#    2728
#    (...)   2743         a MultiIndex will be returned.
#    2744     """
# -> 2745     return map_array(self, mapper, na_action=na_action)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:1715, in map_array(arr, mapper, na_action)
#    1713 values = arr.astype(object, copy=False)
#    1714 if na_action is None:
# -> 1715     return lib.map_infer(values, mapper)
#    1716 else:
#    1717     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
# -> 3071 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/tqdm/std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[27], line 8, in clean_data.<locals>.anonymize_and_extract_spans(text)
#       4         if not isinstance(text, str):
#       5             return pd.Series({'note_content': text, 'fake_name_spans': []})
#       6
#       7         # Analyze
# ----> 8         results = analyzer.analyze(text=text, entities=config.redact_entities, language='en')
#       9
#      10         # Anonymize
#      11         anonymized = anonymizer.anonymize(
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/presidio_analyzer/analyzer_engine.py:223, in AnalyzerEngine.analyze(self, text, language, entities, correlation_id, score_threshold, return_decision_process, ad_hoc_recognizers, context, allow_list, allow_list_match, regex_flags, nlp_artifacts)
#     220 # run the nlp pipeline over the given text, store the results in
#     221 # a NlpArtifacts instance
#     222 if not nlp_artifacts:
# --> 223     nlp_artifacts = self.nlp_engine.process_text(text, language)
#     225 if self.log_decision_process:
#     226     self.app_tracer.trace(
#     227         correlation_id, "nlp artifacts:" + nlp_artifacts.to_json()
#     228     )
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/presidio_analyzer/nlp_engine/spacy_nlp_engine.py:124, in SpacyNlpEngine.process_text(self, text, language)
#     121 if not self.nlp:
#     122     raise ValueError("NLP engine is not loaded. Consider calling .load()")
# --> 124 doc = self.nlp[language](text)
#     125 return self._doc_to_nlp_artifact(doc, language)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/spacy/language.py:1053, in Language.__call__(self, text, disable, component_cfg)
#    1051     error_handler = proc.get_error_handler()
#    1052 try:
# -> 1053     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1054 except KeyError as e:
#    1055     # This typically happens if a component is not initialized
#    1056     raise ValueError(Errors.E109.format(name=name)) from e
#
# File spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
# ---> 52 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/spacy/pipeline/tok2vec.py:120, in Tok2Vec.predict(self, docs)
#     118     width = self.model.get_dim("nO")
#     119     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 120 tokvecs = self.model.predict(docs)
#     121 return tokvecs
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/with_array.py:36, in forward(model, Xseq, is_train)
#      32 def forward(
#      33     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      34 ) -> Tuple[SeqT, Callable]:
#      35     if isinstance(Xseq, Ragged):
# ---> 36         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      37     elif isinstance(Xseq, Padded):
#      38         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/with_array.py:91, in _ragged_forward(model, Xr, is_train)
#      87 def _ragged_forward(
#      88     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      89 ) -> Tuple[Ragged, Callable]:
#      90     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 91     Y, get_dX = layer(Xr.dataXd, is_train)
#      93     def backprop(dYr: Ragged) -> Ragged:
#      94         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/Desktop/CS3D6 Code/.venv/lib/python3.12/site-packages/thinc/layers/maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Pre-Annotation
# Pre-annotate the category spans, pseudonyms, and role (e.g. tenant, leaseholder). This will help speed up manual annotation.
#
# We use regexes for Additional Need categories and for roles. We use the `fake_name_spans` generated in the previous section to highlight automatically generated pseudonyms as names.

# %%
def generate_label_studio_json(df):
    # Construct regexes for ANs & roles & compile
    person_role_regex = r"(?i)\b(tenant|tenants|leaseholder|leaseholders|resident|residents|child|children|son|daughter|partner|wife|husband|mother|father|caller|applicant|neighbour|neighbor|neighbours|neighbor)\b" # common housing roles
    compiled_role_regex = re.compile(person_role_regex)
    compiled_category_regex = {row.cat_label: re.compile(row.regex) for row in taxonomy_v2.itertuples()} # type: ignore

    # Loop through dataframe rows
    label_studio_tasks = []
    for index, row in tqdm(df.iterrows()):
        note_content = str(row['note_content'])
        note_id = str(row['note_id'])
        
        identified_labels = []
        
        # --- AN Tags ---
        for cat_key, compiled_regex in compiled_category_regex.items():
            for match in compiled_regex.finditer(note_content):
                identified_labels.append({
                    "from_name": "need_labels",  # Needs to match Label Studio XML
                    "to_name": "text",
                    "type": "labels",
                    "value": {
                        "start": match.start(), # Extract the specific span - didn't do with the whole dataset as it is expensive.
                        "end": match.end(),
                        "text": match.group(),
                        "labels": [cat_key]
                    }
                })

        # --- Role Labels ---
        for match in compiled_role_regex.finditer(note_content):
            identified_labels.append({
                "from_name": "entity_labels",  # Needs to match Label Studio XML
                "to_name": "text",
                "type": "labels",
                "value": {
                    "start": match.start(),
                    "end": match.end(),
                    "text": match.group(),
                    "labels": ["Person Role"]
                }
            })

        # --- Fake name Spans (Presidio) ---
        for span in row['fake_name_spans']:
            identified_labels.append({
                "from_name": "entity_labels", # Needs to match Label Studio XML
                "to_name": "text",
                "type": "labels",
                "value": {
                    "start": span['start'],
                    "end": span['end'],
                    "text": span['text'],
                    "labels": span['labels']
                }
            })
        
        # --- Construct label studio task ---
        task = {
            "data": {
                "note_content": note_content,
                "id": note_id
            },
            "predictions": [{
                "model_version": "pre_annotated",
                "score": 1.0,
                "result": identified_labels
            }]
        }
        
        label_studio_tasks.append(task)
    return label_studio_tasks

# %%
label_studio_tasks = generate_label_studio_json(scrubbed_df)
len(label_studio_tasks)
# Out:
# 0it [00:00, ?it/s]
# 2000

# %%
label_studio_tasks[1]
# Out:
# {'data': {'note_content': "[Category: tenureManagement] Ending Tenancy  IGNORE PREVIOUS NOTE. I Spoke to Housing Officer for 9 Wilde Close where the tenant has been moved to. Unable to end current tenancy unless new sign up is done at Gabrielle Davis, Gina Moore the housing officer for Abigail Shaffer close confirmed he spoke to the Mr Connie Lawrence's sister who confirmed Cristian Santos is currently in hospital and is unable to do much due to his condition.   tenant's sister stated she would like to collect items from the property but did not confirm the items she wishes to collect (tenant's sister has had the keys for 83 Fellows Court <DATE_TIME> and did not attend the property)  tenant's sister will call me to arrange a time and date to collect items. \n\nMr Daniel Wagner is a severe hoarder the property is not in good condition and there are no visible valuables (pictures taken)",
#   'id': '3846587c-fcd0-470a-b84a-5c87477b2d31'},
#  'predictions': [{'model_version': 'pre_annotated',
#    'score': 1.0,
#    'result': [{'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 771,
#       'end': 778,
#       'text': 'hoarder',
#       'labels': ['cautions_unclean_unsafe_living_environment']}},
#     {'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 379,
#       'end': 390,
#       'text': 'in hospital',
#       'labels': ['health_care_setting']}},
#     {'from_name': 'need_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 771,
#       'end': 778,
#       'text': 'hoarder',
#       'labels': ['housing_conditions_hoarding']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 122,
#       'end': 128,
#       'text': 'tenant',
#       'labels': ['Person Role']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 440,
#       'end': 446,
#       'text': 'tenant',
#       'labels': ['Person Role']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 566,
#       'end': 572,
#       'text': 'tenant',
#       'labels': ['Person Role']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 666,
#       'end': 672,
#       'text': 'tenant',
#       'labels': ['Person Role']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 745,
#       'end': 758,
#       'text': 'Daniel Wagner',
#       'labels': ['Pseudonym']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 350,
#       'end': 365,
#       'text': 'Cristian Santos',
#       'labels': ['Pseudonym']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 311,
#       'end': 326,
#       'text': 'Connie Lawrence',
#       'labels': ['Pseudonym']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 260,
#       'end': 275,
#       'text': 'Abigail Shaffer',
#       'labels': ['Pseudonym']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 225,
#       'end': 235,
#       'text': 'Gina Moore',
#       'labels': ['Pseudonym']}},
#     {'from_name': 'entity_labels',
#      'to_name': 'text',
#      'type': 'labels',
#      'value': {'start': 208,
#       'end': 223,
#       'text': 'Gabrielle Davis',
#       'labels': ['Pseudonym']}}]}]}

# %% [markdown]
# ### Export sample set

# %%
# Annotated examples
with open(config.output_gold_standard_json_path, "w") as f:
    json.dump(label_studio_tasks, f, indent=2)

# %%
# Data without annotations
scrubbed_df.to_csv(config.output_gold_standard_csv_path, index=False)
